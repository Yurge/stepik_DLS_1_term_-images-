# %% [markdown]
# <p style="align: center;"><img align=center src="https://s8.hostingkartinok.com/uploads/images/2018/08/308b49fcfbc619d629fe4604bceb67ac.jpg" width=500 height=450/></p>
#
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>
#
# <h3 style="text-align: center;"><b>Домашнее задание. Полносвязные и свёрточные нейронные сети</b></h3>
#
# В этом занятии вам предстоит потренироваться построению нейронных сетей с помощью библиотеки Pytorch. Делать мы это будем на нескольких датасетах.

# %%
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

import torch
from torch import nn
from torch.nn import functional as F

from torch.utils.data import TensorDataset, DataLoader

sns.set(style="darkgrid", font_scale=1.4)

# %% [markdown]
# # Часть 1. Датасет moons
#
# Давайте сгенерируем датасет и посмотрим на него!

# %%
X, y = make_moons(n_samples=10000, random_state=42, noise=0.1)

# %%
plt.figure(figsize=(16, 10))
plt.title("Dataset")
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="viridis")
plt.show()

# %% [markdown]
# Сделаем train/test split

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=42)

# %% [markdown]
# ### Загрузка данных
# В PyTorch загрузка данных как правило происходит налету (иногда датасеты не помещаются в оперативную память). Для этого используются две сущности `Dataset` и `DataLoader`.
#
# 1.   `Dataset` загружает каждый объект по отдельности.
#
# 2.   `DataLoader` группирует объекты из `Dataset` в батчи.
#
# Так как наш датасет достаточно маленький мы будем использовать `TensorDataset`. Все, что нам нужно, это перевести из массива numpy в тензор с типом `torch.float32`.
#
# ### Задание. Создайте тензоры с обучающими и тестовыми данными

# %%
X_train_t = torch.FloatTensor(X_train)  # YOUR CODE GOES HERE
y_train_t = torch.FloatTensor(y_train)  # YOUR CODE GOES HERE
X_val_t = torch.FloatTensor(X_val)  # YOUR CODE GOES HERE
y_val_t = torch.FloatTensor(y_val)  # YOUR CODE GOES HERE

# X_train_t.dtype

# %% [markdown]
# Создаем `Dataset` и `DataLoader`.

# %%
train_dataset = TensorDataset(X_train_t, y_train_t)
val_dataset = TensorDataset(X_val_t, y_val_t)
train_dataloader = DataLoader(train_dataset, batch_size=128)
val_dataloader = DataLoader(val_dataset, batch_size=128)

# %% [markdown]
# ## Logistic regression is my profession
#
# **Напоминание**
# Давайте вспоним, что происходит в логистической регрессии. На входе у нас есть матрица объект-признак X и столбец-вектор $y$ – метки из $\{0, 1\}$ для каждого объекта. Мы хотим найти такую матрицу весов $W$ и смещение $b$ (bias), что наша модель $XW + b$ будет каким-то образом предсказывать класс объекта. Как видно на выходе наша модель может выдавать число в интервале от $(-\infty;\infty)$. Этот выход как правило называют "логитами" (logits). Нам необходимо перевести его на интервал от $[0;1]$ для того, чтобы он выдавал нам вероятность принадлежности объекта к кассу один, также лучше, чтобы эта функция была монотонной, быстро считалась, имела производную и на $-\infty$ имела значение $0$, а на $+\infty$ имела значение $1$. Такой класс функций называется сигмоидыю. Чаще всего в качестве сигмоида берут
# $$
# \sigma(x) = \frac{1}{1 + e^{-x}}.
# $$

# %% [markdown]
# ### Задание. Реализация логистической регрессии
#
# Вам необходимо написать модуль на PyTorch реализующий $logits = XW + b$, где $W$ и $b$ – параметры (`nn.Parameter`) модели. Иначе говоря, здесь мы реализуем своими руками модуль `nn.Linear` (в этом пункте его использование запрещено). Инициализируйте веса нормальным распределением (`torch.randn`).

# %%
class LinearRegression(nn.Module):
    def __init__(self, in_features: int, out_features: int, bias: bool = True):
        super().__init__()
        self.weights = nn.Parameter(torch.randn(2))         # <YOUR CODE>
        self.bias = bias
        if bias:
            self.bias_term = nn.Parameter(torch.randn(1))   # YOUR CODE GOES HERE

    def forward(self, x):
        x =  x @ self.weights
        if self.bias:
            x += self.bias_term                             # YOUR CODE GOES HERE
        return x

# %%
linear_regression = LinearRegression(2, 1)
loss_function = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(linear_regression.parameters(), lr=0.05)

# %% [markdown]
# **Вопрос 1.** Сколько обучаемых параметров у получившейся модели? Имеется в виду суммарное количество отдельных числовых переменных, а не количество тензоров.

# %%
len(linear_regression.weights) + (1 if linear_regression.bias else 0)    #YOUR CODE
# Out:
# 3

# %% [markdown]
# 3 обучаемых параметра

# %% [markdown]
# ### Train loop
#
# Вот псевдокод, который поможет вам разобраться в том, что происходит во время обучения
#
# ```python
# for epoch in range(max_epochs):  # <----------- итерируемся по датасету несколько раз
#     for x_batch, y_batch in dataset:  # <------ итерируемся по датасету. Так как мы используем SGD а не GD, то берем батчи заданного размера
#         optimizer.zero_grad()  # <------------- обуляем градиенты модели
#         outp = model(x_batch)  # <------------- получаем "логиты" из модели
#         loss = loss_func(outp, y_batch)  # <--- считаем "лосс" для логистической регрессии
#         loss.backward()  # <------------------- считаем градиенты
#         optimizer.step()  # <------------------ делаем шаг градиентного спуска
#         if convergence:  # <------------------- в случае сходимости выходим из цикла
#             break
# ```
#
# В коде ниже добавлено логирование `accuracy` и `loss`.

# %% [markdown]
# ### Задание. Реализация цикла обучения

# %%
tol = 1e-3
losses = []
max_epochs = 100
prev_weights = torch.zeros_like(linear_regression.weights)
stop_it = False
for epoch in range(max_epochs):
    for it, (X_batch, y_batch) in enumerate(train_dataloader):
        optimizer.zero_grad()
        outp = linear_regression(X_batch)  # YOUR CODE. Use linear_regression to get outputs
        loss = loss_function(outp, y_batch)  # YOUR CODE. Compute loss
        loss.backward()
        losses.append(loss.detach().flatten()[0])
        optimizer.step()

        probabilities = F.sigmoid(outp)  # YOUR CODE. Compute probabilities
        preds = (probabilities > 0.5).type(torch.long)
        batch_acc = (preds.flatten() == y_batch).type(torch.float32).sum() / y_batch.size(0)

        if (it + epoch * len(train_dataloader)) % 100 == 0:
            print(f"Iteration: {it + epoch * len(train_dataloader)}\nBatch accuracy: {batch_acc}")
        current_weights = linear_regression.weights.detach().clone()
        if (prev_weights - current_weights).abs().max() < tol:
            print(f"\nIteration: {it + epoch * len(train_dataloader)}.Convergence. Stopping iterations.")
            stop_it = True
            break
        prev_weights = current_weights
    if stop_it:
        break
# Out:
# Iteration: 0
# Batch accuracy: 0.3125
# Iteration: 100
# Batch accuracy: 0.8671875
# Iteration: 200
# Batch accuracy: 0.8671875
# Iteration: 300
# Batch accuracy: 0.9140625
# Iteration: 400
# Batch accuracy: 0.890625
# Iteration: 500
# Batch accuracy: 0.9140625
# Iteration: 600
# Batch accuracy: 0.875
#
# Iteration: 696.Convergence. Stopping iterations.

# %% [markdown]
# **Вопрос 2.** Сколько итераций потребовалось, чтобы алгоритм сошелся?
#
# **Ответ:**
# при первом запуске потребовалось 700 итераций, но если запускать всё заново, то цифра меняется

# %% [markdown]
# ### Визуализируем результаты

# %%
plt.figure(figsize=(12, 8))
plt.plot(range(len(losses)), losses)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %%
import numpy as np

sns.set(style="white")

xx, yy = np.mgrid[-1.5:2.5:.01, -1.:1.5:.01]
grid = np.c_[xx.ravel(), yy.ravel()]
batch = torch.from_numpy(grid).type(torch.float32)
with torch.no_grad():
    probs = torch.sigmoid(linear_regression(batch).reshape(xx.shape))
    probs = probs.numpy().reshape(xx.shape)

f, ax = plt.subplots(figsize=(16, 10))
ax.set_title("Decision boundary", fontsize=14)
contour = ax.contourf(xx, yy, probs, 25, cmap="RdBu",
                      vmin=0, vmax=1)
ax_c = f.colorbar(contour)
ax_c.set_label("$P(y = 1)$")
ax_c.set_ticks([0, .25, .5, .75, 1])

ax.scatter(X[100:,0], X[100:, 1], c=y[100:], s=50,
           cmap="RdBu", vmin=-.2, vmax=1.2,
           edgecolor="white", linewidth=1)

ax.set(xlabel="$X_1$", ylabel="$X_2$")
plt.show()

# %% [markdown]
# ### Задание. Реализуйте predict и посчитайте accuracy на test.

# %%
@torch.no_grad()
def predict(dataloader, model):
    model.eval()
    predictions = np.array([])
    for x_batch, _ in dataloader:
        outp = model(x_batch)     #<YOUR CODE>
        probabilities = F.sigmoid(outp)  #YOUR CODE. Compute predictions
        preds = (probabilities > 0.5).type(torch.long)
        predictions = np.hstack((predictions, preds.numpy().flatten()))
    return predictions.flatten()

# %%
from sklearn.metrics import accuracy_score

predicts = predict(val_dataloader, linear_regression)
total_accuracy_by_test = accuracy_score(y_val, predicts)    # YOUR CODE. Compute total accuracy

f'total accuracy: {total_accuracy_by_test}'
# Out:
# 'total accuracy: 0.8724'

# %% [markdown]
# **Вопрос 3**
#
# Какое `accuracy` получается после обучения?
#
# **Ответ:**
# 0.8636
#
# при перезапуске всего ноутбука цифра незначительно меняется

# %% [markdown]
# # Часть 2. Датасет MNIST
# Датасет MNIST содержит рукописные цифры. Загрузим датасет и создадим DataLoader-ы. Пример можно найти в семинаре по полносвязным нейронным сетям.

# %%
import os
from torchvision.datasets import MNIST
from torchvision import transforms as tfs


data_tfs = tfs.Compose([
    tfs.ToTensor(),
    tfs.Normalize((0.5), (0.5))
])

# install for train and test
root = './'
train_dataset = MNIST(root, train=True,  transform=data_tfs, download=True)
val_dataset  = MNIST(root, train=False, transform=data_tfs, download=True)

train_dataloader = DataLoader(train_dataset, batch_size=100)  # YOUR CODE GOES HERE
valid_dataloader = DataLoader(val_dataset, batch_size=100)  # YOUR CODE GOES HERE
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 15.9MB/s]
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 495kB/s]
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.41MB/s]
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 4.40MB/s]
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw

# %% [markdown]
# ## Часть 2.1. Полносвязные нейронные сети
# Сначала решим MNIST с помощью полносвязной нейронной сети.

# %%
class Identical(nn.Module):
    def forward(self, x):
        return x

# %% [markdown]
# ### Задание. Простая полносвязная нейронная сеть
#
# Создайте полносвязную нейронную сеть с помощью класса Sequential. Сеть состоит из:
# * Уплощения матрицы в вектор (nn.Flatten);
# * Двух скрытых слоёв из 128 нейронов с активацией nn.ELU;
# * Выходного слоя с 10 нейронами.
#
# Задайте лосс для обучения (кросс-энтропия).

# %%
activation = nn.ELU

model = nn.Sequential(
    nn.Flatten(),
    #YOUR CODE. Add layers to your sequential class,
    nn.Linear(784, 128),
    activation(),
    nn.Linear(128, 128),
    activation(),
    nn.Linear(128, 10)
)

# %%
criterion = nn.CrossEntropyLoss()   #YOUR CODE. Select a loss function
optimizer = torch.optim.Adam(model.parameters())

loaders = {"train": train_dataloader, "valid": valid_dataloader}

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ### Train loop (seriously)
#
# Давайте разберемся с кодом ниже, который подойдет для 90% задач в будущем.
#
#
# ```python
# for epoch in range(max_epochs):  # <--------------- итерируемся по датасету несколько раз
#     for k, dataloader in loaders.items():  # <----- несколько dataloader для train / valid / test
#         for x_batch, y_batch in dataloader:  # <--- итерируемся по датасету. Так как мы используем SGD а не GD, то берем батчи заданного размера
#             if k == "train":
#                 model.train()  # <------------------ переводим модель в режим train
#                 optimizer.zero_grad()  # <--------- обнуляем градиенты модели
#                 outp = model(x_batch)
#                 loss = criterion(outp, y_batch) # <-считаем "лосс" для логистической регрессии
#                 loss.backward()  # <--------------- считаем градиенты
#                 optimizer.step()  # <-------------- делаем шаг градиентного спуска
#             else:  # <----------------------------- test/eval
#                 model.eval()  # <------------------ переводим модель в режим eval
#                 with torch.no_grad():  # <--------- НЕ считаем градиенты
#                     outp = model(x_batch)  # <------------- получаем "логиты" из модели
#             count_metrics(outp, y_batch)  # <-------------- считаем метрики
# ```

# %% [markdown]
# ### Задание. Дополните цикл обучения.

# %%
import tqdm

max_epochs = 10
accuracy = {"train": [], "valid": []}
for epoch in tqdm.tqdm(range(max_epochs), deskc='Цикл по Эпохам'):
    for k, dataloader in loaders.items():
        epoch_correct = 0
        epoch_all = 0
        for x_batch, y_batch in tqdm.tqdm(dataloader, desk='Цикл по минибатчам'):
            if k == "train":
                 # YOUR CODE. Set model to ``train`` mode and calculate outputs. Don't forget zero_grad!
                 model.train()
                 optimizer.zero_grad()
                 outp = model(x_batch)
            else:
                 # YOUR CODE. Set model to ``eval`` mode and calculate outputs
                 model.eval()
                 with torch.no_grad():
                    outp = model(x_batch)
            preds = outp.argmax(-1)
            correct = sum(preds == y_batch)     # YOUR CODE GOES HERE
            all = len(preds)                    # YOUR CODE GOES HERE
            epoch_correct += correct.item()
            epoch_all += all
            if k == "train":
                loss = criterion(outp, y_batch)
                # YOUR CODE. Calculate gradients and make a step of your optimizer
                loss.backward()
                optimizer.step()
        if k == "train":
            print(f"Epoch: {epoch+1}")
        print(f"Loader: {k}. Accuracy: {epoch_correct/epoch_all}")
        accuracy[k].append(epoch_correct/epoch_all)
# Out:
# Цикл по Эпохам:   0%|          | 0/10 [00:00<?, ?it/s]
# Цикл по минибатчам:   0%|          | 0/600 [00:00<?, ?it/s]
# Цикл по минибатчам:   0%|          | 1/600 [00:00<01:07,  8.89it/s]
# Цикл по минибатчам:   1%|          | 4/600 [00:00<00:32, 18.25it/s]
# Цикл по минибатчам:   1%|          | 7/600 [00:00<00:26, 22.17it/s]
# Цикл по минибатчам:   2%|▏         | 10/600 [00:00<00:25, 23.46it/s]
# Цикл по минибатчам:   2%|▏         | 13/600 [00:00<00:23, 25.34it/s]
# Цикл по минибатчам:   3%|▎         | 16/600 [00:00<00:22, 25.59it/s]
# Цикл по минибатчам:   3%|▎         | 19/600 [00:00<00:21, 26.53it/s]
# Цикл по минибатчам:   4%|▎         | 22/600 [00:00<00:21, 27.40it/s]
# Цикл по минибатчам:   4%|▍         | 25/600 [00:01<00:21, 26.15it/s]
# Цикл по минибатчам:   5%|▍         | 28/600 [00:01<00:22, 25.26it/s]
# Цикл по минибатчам:   5%|▌         | 31/600 [00:01<00:22, 25.13it/s]
# Цикл по минибатчам:   6%|▌         | 36/600 [00:01<00:18, 30.71it/s]
# Цикл по минибатчам:   7%|▋         | 41/600 [00:01<00:16, 34.62it/s]
# Цикл по минибатчам:   8%|▊         | 46/600 [00:01<00:14, 37.25it/s]
# Цикл по минибатчам:   8%|▊         | 51/600 [00:01<00:13, 39.51it/s]
# Цикл по минибатчам:   9%|▉         | 56/600 [00:01<00:13, 40.71it/s]
# Цикл по минибатчам:  10%|█         | 61/600 [00:01<00:12, 41.57it/s]
# Цикл по минибатчам:  11%|█         | 66/600 [00:02<00:13, 40.40it/s]
# Цикл по минибатчам:  12%|█▏        | 71/600 [00:02<00:13, 40.35it/s]
# Цикл по минибатчам:  13%|█▎        | 76/600 [00:02<00:13, 40.21it/s]
# Цикл по минибатчам:  14%|█▎        | 81/600 [00:02<00:12, 41.26it/s]
# Цикл по минибатчам:  14%|█▍        | 86/600 [00:02<00:12, 42.50it/s]
# Цикл по минибатчам:  15%|█▌        | 91/600 [00:02<00:11, 43.34it/s]
# Цикл по минибатчам:  16%|█▌        | 96/600 [00:02<00:11, 44.27it/s]
# Цикл по минибатчам:  17%|█▋        | 101/600 [00:02<00:11, 44.45it/s]
# Цикл по минибатчам:  18%|█▊        | 106/600 [00:02<00:11, 44.73it/s]
# Цикл по минибатчам:  18%|█▊        | 111/600 [00:03<00:12, 40.42it/s]
# Цикл по минибатчам:  19%|█▉        | 116/600 [00:03<00:11, 41.84it/s]
# Цикл по минибатчам:  20%|██        | 121/600 [00:03<00:11, 40.96it/s]
# Цикл по минибатчам:  21%|██        | 126/600 [00:03<00:11, 42.06it/s]
# Цикл по минибатчам:  22%|██▏       | 131/600 [00:03<00:10, 42.67it/s]
# Цикл по минибатчам:  23%|██▎       | 136/600 [00:03<00:10, 42.85it/s]
# Цикл по минибатчам:  24%|██▎       | 141/600 [00:03<00:10, 43.35it/s]
# Цикл по минибатчам:  24%|██▍       | 146/600 [00:03<00:10, 44.01it/s]
# Цикл по минибатчам:  25%|██▌       | 151/600 [00:04<00:10, 42.06it/s]
# Цикл по минибатчам:  26%|██▌       | 156/600 [00:04<00:10, 41.15it/s]
# Цикл по минибатчам:  27%|██▋       | 161/600 [00:04<00:10, 41.06it/s]
# Цикл по минибатчам:  28%|██▊       | 166/600 [00:04<00:10, 41.92it/s]
# Цикл по минибатчам:  28%|██▊       | 171/600 [00:04<00:10, 42.26it/s]
# Цикл по минибатчам:  29%|██▉       | 176/600 [00:04<00:09, 43.04it/s]
# Цикл по минибатчам:  30%|███       | 181/600 [00:04<00:09, 42.96it/s]
# Цикл по минибатчам:  31%|███       | 186/600 [00:04<00:09, 42.84it/s]
# Цикл по минибатчам:  32%|███▏      | 191/600 [00:05<00:09, 43.52it/s]
# Цикл по минибатчам:  33%|███▎      | 196/600 [00:05<00:10, 38.67it/s]
# Цикл по минибатчам:  34%|███▎      | 201/600 [00:05<00:09, 40.51it/s]
# Цикл по минибатчам:  34%|███▍      | 206/600 [00:05<00:09, 39.74it/s]
# Цикл по минибатчам:  35%|███▌      | 211/600 [00:05<00:09, 40.29it/s]
# Цикл по минибатчам:  36%|███▌      | 216/600 [00:05<00:09, 41.65it/s]
# Цикл по минибатчам:  37%|███▋      | 221/600 [00:05<00:08, 42.70it/s]
# Цикл по минибатчам:  38%|███▊      | 226/600 [00:05<00:08, 43.54it/s]
# Цикл по минибатчам:  38%|███▊      | 231/600 [00:05<00:08, 42.84it/s]
# Цикл по минибатчам:  39%|███▉      | 236/600 [00:06<00:09, 40.08it/s]
# Цикл по минибатчам:  40%|████      | 241/600 [00:06<00:08, 41.49it/s]
# Цикл по минибатчам:  41%|████      | 246/600 [00:06<00:08, 41.58it/s]
# Цикл по минибатчам:  42%|████▏     | 251/600 [00:06<00:08, 40.62it/s]
# Цикл по минибатчам:  43%|████▎     | 256/600 [00:06<00:08, 41.95it/s]
# Цикл по минибатчам:  44%|████▎     | 261/600 [00:06<00:07, 42.66it/s]
# Цикл по минибатчам:  44%|████▍     | 266/600 [00:06<00:07, 43.64it/s]
# Цикл по минибатчам:  45%|████▌     | 271/600 [00:06<00:07, 43.98it/s]
# Цикл по минибатчам:  46%|████▌     | 276/600 [00:07<00:07, 43.68it/s]
# Цикл по минибатчам:  47%|████▋     | 281/600 [00:07<00:07, 40.96it/s]
# Цикл по минибатчам:  48%|████▊     | 286/600 [00:07<00:07, 41.61it/s]
# Цикл по минибатчам:  48%|████▊     | 291/600 [00:07<00:07, 41.32it/s]
# Цикл по минибатчам:  49%|████▉     | 296/600 [00:07<00:07, 42.44it/s]
# Цикл по минибатчам:  50%|█████     | 301/600 [00:07<00:06, 43.22it/s]
# Цикл по минибатчам:  51%|█████     | 306/600 [00:07<00:06, 43.70it/s]
# Цикл по минибатчам:  52%|█████▏    | 311/600 [00:07<00:06, 44.03it/s]
# Цикл по минибатчам:  53%|█████▎    | 316/600 [00:07<00:06, 44.35it/s]
# Цикл по минибатчам:  54%|█████▎    | 321/600 [00:08<00:06, 41.26it/s]
# Цикл по минибатчам:  54%|█████▍    | 326/600 [00:08<00:06, 41.43it/s]
# Цикл по минибатчам:  55%|█████▌    | 331/600 [00:08<00:06, 42.94it/s]
# Цикл по минибатчам:  56%|█████▌    | 336/600 [00:08<00:06, 42.14it/s]
# Цикл по минибатчам:  57%|█████▋    | 341/600 [00:08<00:05, 43.28it/s]
# Цикл по минибатчам:  58%|█████▊    | 346/600 [00:08<00:05, 43.61it/s]
# Цикл по минибатчам:  58%|█████▊    | 351/600 [00:08<00:05, 44.17it/s]
# Цикл по минибатчам:  59%|█████▉    | 356/600 [00:08<00:05, 44.66it/s]
# Цикл по минибатчам:  60%|██████    | 361/600 [00:09<00:05, 45.37it/s]
# Цикл по минибатчам:  61%|██████    | 366/600 [00:09<00:05, 42.19it/s]
# Цикл по минибатчам:  62%|██████▏   | 371/600 [00:09<00:05, 43.13it/s]
# Цикл по минибатчам:  63%|██████▎   | 376/600 [00:09<00:05, 43.15it/s]
# Цикл по минибатчам:  64%|██████▎   | 381/600 [00:09<00:05, 42.59it/s]
# Цикл по минибатчам:  64%|██████▍   | 386/600 [00:09<00:04, 43.77it/s]
# Цикл по минибатчам:  65%|██████▌   | 391/600 [00:09<00:04, 43.98it/s]
# Цикл по минибатчам:  66%|██████▌   | 396/600 [00:09<00:04, 44.71it/s]
# Цикл по минибатчам:  67%|██████▋   | 401/600 [00:09<00:04, 44.93it/s]
# Цикл по минибатчам:  68%|██████▊   | 406/600 [00:10<00:04, 44.18it/s]
# Цикл по минибатчам:  68%|██████▊   | 411/600 [00:10<00:04, 41.64it/s]
# Цикл по минибатчам:  69%|██████▉   | 416/600 [00:10<00:04, 41.50it/s]
# Цикл по минибатчам:  70%|███████   | 421/600 [00:10<00:04, 41.51it/s]
# Цикл по минибатчам:  71%|███████   | 426/600 [00:10<00:04, 41.15it/s]
# Цикл по минибатчам:  72%|███████▏  | 431/600 [00:10<00:04, 42.16it/s]
# Цикл по минибатчам:  73%|███████▎  | 436/600 [00:10<00:03, 43.18it/s]
# Цикл по минибатчам:  74%|███████▎  | 441/600 [00:10<00:03, 44.04it/s]
# Цикл по минибатчам:  74%|███████▍  | 446/600 [00:10<00:03, 44.77it/s]
# Цикл по минибатчам:  75%|███████▌  | 451/600 [00:11<00:03, 41.56it/s]
# Цикл по минибатчам:  76%|███████▌  | 456/600 [00:11<00:03, 42.02it/s]
# Цикл по минибатчам:  77%|███████▋  | 461/600 [00:11<00:03, 35.96it/s]
# Цикл по минибатчам:  78%|███████▊  | 465/600 [00:11<00:04, 33.35it/s]
# Цикл по минибатчам:  78%|███████▊  | 469/600 [00:11<00:04, 32.55it/s]
# Цикл по минибатчам:  79%|███████▉  | 473/600 [00:11<00:03, 32.55it/s]
# Цикл по минибатчам:  80%|███████▉  | 477/600 [00:11<00:03, 32.67it/s]
# Цикл по минибатчам:  80%|████████  | 481/600 [00:12<00:03, 31.32it/s]
# Цикл по минибатчам:  81%|████████  | 485/600 [00:12<00:03, 32.00it/s]
# Цикл по минибатчам:  82%|████████▏ | 489/600 [00:12<00:03, 32.52it/s]
# Цикл по минибатчам:  82%|████████▏ | 493/600 [00:12<00:03, 32.84it/s]
# Цикл по минибатчам:  83%|████████▎ | 497/600 [00:12<00:03, 30.73it/s]
# Цикл по минибатчам:  84%|████████▎ | 501/600 [00:12<00:03, 30.33it/s]
# Цикл по минибатчам:  84%|████████▍ | 505/600 [00:12<00:03, 29.99it/s]
# Цикл по минибатчам:  85%|████████▍ | 509/600 [00:13<00:03, 29.20it/s]
# Цикл по минибатчам:  85%|████████▌ | 512/600 [00:13<00:03, 27.94it/s]
# Цикл по минибатчам:  86%|████████▌ | 515/600 [00:13<00:03, 26.87it/s]
# Цикл по минибатчам:  86%|████████▋ | 518/600 [00:13<00:02, 27.35it/s]
# Цикл по минибатчам:  87%|████████▋ | 521/600 [00:13<00:02, 27.31it/s]
# Цикл по минибатчам:  87%|████████▋ | 524/600 [00:13<00:02, 26.44it/s]
# Цикл по минибатчам:  88%|████████▊ | 527/600 [00:13<00:02, 25.50it/s]
# Цикл по минибатчам:  89%|████████▊ | 532/600 [00:13<00:02, 30.31it/s]
# Цикл по минибатчам:  90%|████████▉ | 537/600 [00:13<00:01, 34.51it/s]
# Цикл по минибатчам:  90%|█████████ | 541/600 [00:14<00:01, 35.69it/s]
# Цикл по минибатчам:  91%|█████████ | 545/600 [00:14<00:01, 36.26it/s]
# Цикл по минибатчам:  92%|█████████▏| 550/600 [00:14<00:01, 38.63it/s]
# Цикл по минибатчам:  92%|█████████▎| 555/600 [00:14<00:01, 40.77it/s]
# Цикл по минибатчам:  93%|█████████▎| 560/600 [00:14<00:00, 41.90it/s]
# Цикл по минибатчам:  94%|█████████▍| 565/600 [00:14<00:00, 43.42it/s]
# Цикл по минибатчам:  95%|█████████▌| 570/600 [00:14<00:00, 42.51it/s]
# Цикл по минибатчам:  96%|█████████▌| 575/600 [00:14<00:00, 43.75it/s]
# Цикл по минибатчам:  97%|█████████▋| 580/600 [00:14<00:00, 44.13it/s]
# Цикл по минибатчам:  98%|█████████▊| 585/600 [00:15<00:00, 42.06it/s]
# Цикл по минибатчам:  98%|█████████▊| 590/600 [00:15<00:00, 41.21it/s]
# Цикл по минибатчам:  99%|█████████▉| 595/600 [00:15<00:00, 42.29it/s]
# Цикл по минибатчам: 100%|██████████| 600/600 [00:15<00:00, 38.84it/s]
# Epoch: 1
# Loader: train. Accuracy: 0.8876666666666667
# Цикл по минибатчам:   0%|          | 0/100 [00:00<?, ?it/s]
# Цикл по минибатчам:   6%|▌         | 6/100 [00:00<00:01, 52.79it/s]
# Цикл по минибатчам:  12%|█▏        | 12/100 [00:00<00:01, 46.53it/s]
# Цикл по минибатчам:  17%|█▋        | 17/100 [00:00<00:01, 47.60it/s]
# Цикл по минибатчам:  22%|██▏       | 22/100 [00:00<00:01, 47.66it/s]
# Цикл по минибатчам:  27%|██▋       | 27/100 [00:00<00:01, 46.72it/s]
# Цикл по минибатчам:  32%|███▏      | 32/100 [00:00<00:01, 42.00it/s]
# Цикл по минибатчам:  37%|███▋      | 37/100 [00:00<00:01, 42.82it/s]
# Цикл по минибатчам:  42%|████▏     | 42/100 [00:00<00:01, 43.51it/s]
# Цикл по минибатчам:  47%|████▋     | 47/100 [00:01<00:01, 45.07it/s]
# Цикл по минибатчам:  52%|█████▏    | 52/100 [00:01<00:01, 45.65it/s]
# Цикл по минибатчам:  57%|█████▋    | 57/100 [00:01<00:00, 45.11it/s]
# Цикл по минибатчам:  62%|██████▏   | 62/100 [00:01<00:00, 46.29it/s]
# Цикл по минибатчам:  67%|██████▋   | 67/100 [00:01<00:00, 46.52it/s]
# Цикл по минибатчам:  72%|███████▏  | 72/100 [00:01<00:00, 46.38it/s]
# Цикл по минибатчам:  77%|███████▋  | 77/100 [00:01<00:00, 43.13it/s]
# Цикл по минибатчам:  82%|████████▏ | 82/100 [00:01<00:00, 44.54it/s]
# Цикл по минибатчам:  87%|████████▋ | 87/100 [00:01<00:00, 45.90it/s]
# Цикл по минибатчам:  92%|█████████▏| 92/100 [00:02<00:00, 46.85it/s]
# Цикл по минибатчам: 100%|██████████| 100/100 [00:02<00:00, 45.83it/s]
# Цикл по Эпохам:  10%|█         | 1/10 [00:17<02:38, 17.66s/it]
# Loader: valid. Accuracy: 0.9246
# Цикл по минибатчам:   0%|          | 0/600 [00:00<?, ?it/s]
# Цикл по минибатчам:   1%|          | 4/600 [00:00<00:15, 38.68it/s]
# Цикл по минибатчам:   2%|▏         | 9/600 [00:00<00:13, 43.08it/s]
# Цикл по минибатчам:   2%|▏         | 14/600 [00:00<00:13, 44.30it/s]
# Цикл по минибатчам:   3%|▎         | 19/600 [00:00<00:14, 41.06it/s]
# Цикл по минибатчам:   4%|▍         | 24/600 [00:00<00:14, 40.39it/s]
# Цикл по минибатчам:   5%|▍         | 29/600 [00:00<00:13, 41.58it/s]
# Цикл по минибатчам:   6%|▌         | 34/600 [00:00<00:13, 42.17it/s]
# Цикл по минибатчам:   6%|▋         | 39/600 [00:00<00:12, 43.60it/s]
# Цикл по минибатчам:   7%|▋         | 44/600 [00:01<00:12, 44.34it/s]
# Цикл по минибатчам:   8%|▊         | 49/600 [00:01<00:12, 42.98it/s]
# Цикл по минибатчам:   9%|▉         | 54/600 [00:01<00:12, 43.38it/s]
# Цикл по минибатчам:  10%|▉         | 59/600 [00:01<00:12, 43.39it/s]
# Цикл по минибатчам:  11%|█         | 64/600 [00:01<00:12, 41.50it/s]
# Цикл по минибатчам:  12%|█▏        | 69/600 [00:01<00:12, 42.07it/s]
# Цикл по минибатчам:  12%|█▏        | 74/600 [00:01<00:12, 42.65it/s]
# Цикл по минибатчам:  13%|█▎        | 79/600 [00:01<00:11, 43.48it/s]
# Цикл по минибатчам:  14%|█▍        | 84/600 [00:01<00:11, 44.41it/s]
# Цикл по минибатчам:  15%|█▍        | 89/600 [00:02<00:11, 44.61it/s]
# Цикл по минибатчам:  16%|█▌        | 94/600 [00:02<00:11, 42.94it/s]
# Цикл по минибатчам:  16%|█▋        | 99/600 [00:02<00:11, 43.39it/s]
# Цикл по минибатчам:  17%|█▋        | 104/600 [00:02<00:12, 41.12it/s]
# Цикл по минибатчам:  18%|█▊        | 109/600 [00:02<00:11, 41.02it/s]
# Цикл по минибатчам:  19%|█▉        | 114/600 [00:02<00:11, 42.08it/s]
# Цикл по минибатчам:  20%|█▉        | 119/600 [00:02<00:11, 43.26it/s]
# Цикл по минибатчам:  21%|██        | 124/600 [00:02<00:10, 43.88it/s]
# Цикл по минибатчам:  22%|██▏       | 129/600 [00:03<00:10, 44.78it/s]
# Цикл по минибатчам:  22%|██▏       | 134/600 [00:03<00:10, 44.69it/s]
# Цикл по минибатчам:  23%|██▎       | 139/600 [00:03<00:10, 43.76it/s]
# Цикл по минибатчам:  24%|██▍       | 144/600 [00:03<00:10, 44.08it/s]
# Цикл по минибатчам:  25%|██▍       | 149/600 [00:03<00:11, 39.94it/s]
# Цикл по минибатчам:  26%|██▌       | 154/600 [00:03<00:11, 40.01it/s]
# Цикл по минибатчам:  26%|██▋       | 159/600 [00:03<00:10, 41.16it/s]
# Цикл по минибатчам:  27%|██▋       | 164/600 [00:03<00:10, 42.38it/s]
# Цикл по минибатчам:  28%|██▊       | 169/600 [00:03<00:09, 43.57it/s]
# Цикл по минибатчам:  29%|██▉       | 174/600 [00:04<00:09, 43.54it/s]
# Цикл по минибатчам:  30%|██▉       | 179/600 [00:04<00:09, 42.94it/s]
# Цикл по минибатчам:  31%|███       | 184/600 [00:04<00:09, 43.28it/s]
# Цикл по минибатчам:  32%|███▏      | 189/600 [00:04<00:09, 41.31it/s]
# Цикл по минибатчам:  32%|███▏      | 194/600 [00:04<00:09, 41.27it/s]
# Цикл по минибатчам:  33%|███▎      | 199/600 [00:04<00:09, 42.03it/s]
# Цикл по минибатчам:  34%|███▍      | 204/600 [00:04<00:09, 43.13it/s]
# Цикл по минибатчам:  35%|███▍      | 209/600 [00:04<00:08, 43.83it/s]
# Цикл по минибатчам:  36%|███▌      | 214/600 [00:05<00:08, 44.20it/s]
# Цикл по минибатчам:  36%|███▋      | 219/600 [00:05<00:08, 44.21it/s]
# Цикл по минибатчам:  37%|███▋      | 224/600 [00:05<00:08, 43.25it/s]
# Цикл по минибатчам:  38%|███▊      | 229/600 [00:05<00:08, 44.09it/s]
# Цикл по минибатчам:  39%|███▉      | 234/600 [00:05<00:08, 40.74it/s]
# Цикл по минибатчам:  40%|███▉      | 239/600 [00:05<00:08, 42.21it/s]
# Цикл по минибатчам:  41%|████      | 244/600 [00:05<00:08, 43.43it/s]
# Цикл по минибатчам:  42%|████▏     | 249/600 [00:05<00:07, 44.19it/s]
# Цикл по минибатчам:  42%|████▏     | 254/600 [00:05<00:07, 44.48it/s]
# Цикл по минибатчам:  43%|████▎     | 259/600 [00:06<00:07, 45.15it/s]
# Цикл по минибатчам:  44%|████▍     | 264/600 [00:06<00:07, 42.21it/s]
# Цикл по минибатчам:  45%|████▍     | 269/600 [00:06<00:08, 36.95it/s]
# Цикл по минибатчам:  46%|████▌     | 273/600 [00:06<00:09, 32.72it/s]
# Цикл по минибатчам:  46%|████▌     | 277/600 [00:06<00:09, 32.75it/s]
# Цикл по минибатчам:  47%|████▋     | 281/600 [00:06<00:09, 32.93it/s]
# Цикл по минибатчам:  48%|████▊     | 285/600 [00:06<00:09, 33.07it/s]
# Цикл по минибатчам:  48%|████▊     | 289/600 [00:06<00:09, 33.07it/s]
# Цикл по минибатчам:  49%|████▉     | 293/600 [00:07<00:09, 33.31it/s]
# Цикл по минибатчам:  50%|████▉     | 297/600 [00:07<00:08, 33.68it/s]
# Цикл по минибатчам:  50%|█████     | 301/600 [00:07<00:09, 33.01it/s]
# Цикл по минибатчам:  51%|█████     | 305/600 [00:07<00:09, 30.44it/s]
# Цикл по минибатчам:  52%|█████▏    | 309/600 [00:07<00:10, 28.24it/s]
# Цикл по минибатчам:  52%|█████▏    | 312/600 [00:07<00:10, 28.09it/s]
# Цикл по минибатчам:  52%|█████▎    | 315/600 [00:07<00:10, 27.31it/s]
# Цикл по минибатчам:  53%|█████▎    | 318/600 [00:08<00:10, 27.62it/s]
# Цикл по минибатчам:  54%|█████▎    | 321/600 [00:08<00:10, 27.06it/s]
# Цикл по минибатчам:  54%|█████▍    | 324/600 [00:08<00:10, 27.28it/s]
# Цикл по минибатчам:  55%|█████▍    | 327/600 [00:08<00:10, 26.89it/s]
# Цикл по минибатчам:  55%|█████▌    | 330/600 [00:08<00:10, 26.09it/s]
# Цикл по минибатчам:  56%|█████▌    | 333/600 [00:08<00:10, 26.07it/s]
# Цикл по минибатчам:  56%|█████▌    | 336/600 [00:08<00:10, 26.13it/s]
# Цикл по минибатчам:  56%|█████▋    | 339/600 [00:08<00:10, 25.82it/s]
# Цикл по минибатчам:  57%|█████▋    | 344/600 [00:08<00:08, 31.02it/s]
# Цикл по минибатчам:  58%|█████▊    | 349/600 [00:09<00:07, 35.03it/s]
# Цикл по минибатчам:  59%|█████▉    | 354/600 [00:09<00:06, 37.75it/s]
# Цикл по минибатчам:  60%|█████▉    | 359/600 [00:09<00:06, 39.78it/s]
# Цикл по минибатчам:  61%|██████    | 364/600 [00:09<00:05, 39.63it/s]
# Цикл по минибатчам:  61%|██████▏   | 368/600 [00:09<00:06, 38.48it/s]
# Цикл по минибатчам:  62%|██████▏   | 373/600 [00:09<00:05, 38.83it/s]
# Цикл по минибатчам:  63%|██████▎   | 377/600 [00:09<00:06, 37.08it/s]
# Цикл по минибатчам:  64%|██████▎   | 381/600 [00:09<00:05, 37.30it/s]
# Цикл по минибатчам:  64%|██████▍   | 386/600 [00:09<00:05, 39.53it/s]
# Цикл по минибатчам:  65%|██████▌   | 391/600 [00:10<00:05, 41.06it/s]
# Цикл по минибатчам:  66%|██████▌   | 396/600 [00:10<00:04, 42.33it/s]
# Цикл по минибатчам:  67%|██████▋   | 401/600 [00:10<00:04, 42.76it/s]
# Цикл по минибатчам:  68%|██████▊   | 406/600 [00:10<00:04, 40.04it/s]
# Цикл по минибатчам:  68%|██████▊   | 411/600 [00:10<00:04, 38.91it/s]
# Цикл по минибатчам:  69%|██████▉   | 416/600 [00:10<00:04, 39.81it/s]
# Цикл по минибатчам:  70%|███████   | 421/600 [00:10<00:04, 41.15it/s]
# Цикл по минибатчам:  71%|███████   | 426/600 [00:10<00:04, 42.39it/s]
# Цикл по минибатчам:  72%|███████▏  | 431/600 [00:11<00:03, 43.29it/s]
# Цикл по минибатчам:  73%|███████▎  | 436/600 [00:11<00:03, 43.39it/s]
# Цикл по минибатчам:  74%|███████▎  | 441/600 [00:11<00:03, 43.82it/s]
# Цикл по минибатчам:  74%|███████▍  | 446/600 [00:11<00:03, 43.99it/s]
# Цикл по минибатчам:  75%|███████▌  | 451/600 [00:11<00:03, 40.55it/s]
# Цикл по минибатчам:  76%|███████▌  | 456/600 [00:11<00:03, 41.10it/s]
# Цикл по минибатчам:  77%|███████▋  | 461/600 [00:11<00:03, 42.26it/s]
# Цикл по минибатчам:  78%|███████▊  | 466/600 [00:11<00:03, 43.23it/s]
# Цикл по минибатчам:  78%|███████▊  | 471/600 [00:11<00:02, 44.10it/s]
# Цикл по минибатчам:  79%|███████▉  | 476/600 [00:12<00:02, 44.44it/s]
# Цикл по минибатчам:  80%|████████  | 481/600 [00:12<00:02, 44.77it/s]
# Цикл по минибатчам:  81%|████████  | 486/600 [00:12<00:02, 44.56it/s]
# Цикл по минибатчам:  82%|████████▏ | 491/600 [00:12<00:02, 43.03it/s]
# Цикл по минибатчам:  83%|████████▎ | 496/600 [00:12<00:02, 40.67it/s]
# Цикл по минибатчам:  84%|████████▎ | 501/600 [00:12<00:02, 41.94it/s]
# Цикл по минибатчам:  84%|████████▍ | 506/600 [00:12<00:02, 42.43it/s]
# Цикл по минибатчам:  85%|████████▌ | 511/600 [00:12<00:02, 43.27it/s]
# Цикл по минибатчам:  86%|████████▌ | 516/600 [00:13<00:01, 43.88it/s]
# Цикл по минибатчам:  87%|████████▋ | 521/600 [00:13<00:01, 44.06it/s]
# Цикл по минибатчам:  88%|████████▊ | 526/600 [00:13<00:01, 44.65it/s]
# Цикл по минибатчам:  88%|████████▊ | 531/600 [00:13<00:01, 44.34it/s]
# Цикл по минибатчам:  89%|████████▉ | 536/600 [00:13<00:01, 40.86it/s]
# Цикл по минибатчам:  90%|█████████ | 541/600 [00:13<00:01, 41.10it/s]
# Цикл по минибатчам:  91%|█████████ | 546/600 [00:13<00:01, 41.57it/s]
# Цикл по минибатчам:  92%|█████████▏| 551/600 [00:13<00:01, 42.46it/s]
# Цикл по минибатчам:  93%|█████████▎| 556/600 [00:13<00:01, 43.63it/s]
# Цикл по минибатчам:  94%|█████████▎| 561/600 [00:14<00:00, 43.98it/s]
# Цикл по минибатчам:  94%|█████████▍| 566/600 [00:14<00:00, 44.49it/s]
# Цикл по минибатчам:  95%|█████████▌| 571/600 [00:14<00:00, 44.41it/s]
# Цикл по минибатчам:  96%|█████████▌| 576/600 [00:14<00:00, 43.89it/s]
# Цикл по минибатчам:  97%|█████████▋| 581/600 [00:14<00:00, 40.51it/s]
# Цикл по минибатчам:  98%|█████████▊| 586/600 [00:14<00:00, 41.16it/s]
# Цикл по минибатчам:  98%|█████████▊| 591/600 [00:14<00:00, 42.49it/s]
# Цикл по минибатчам: 100%|██████████| 600/600 [00:14<00:00, 40.10it/s]
# Epoch: 2
# Loader: train. Accuracy: 0.9450666666666667
# Цикл по минибатчам:   0%|          | 0/100 [00:00<?, ?it/s]
# Цикл по минибатчам:   6%|▌         | 6/100 [00:00<00:01, 50.77it/s]
# Цикл по минибатчам:  12%|█▏        | 12/100 [00:00<00:01, 50.19it/s]
# Цикл по минибатчам:  18%|█▊        | 18/100 [00:00<00:01, 49.67it/s]
# Цикл по минибатчам:  23%|██▎       | 23/100 [00:00<00:01, 44.99it/s]
# Цикл по минибатчам:  28%|██▊       | 28/100 [00:00<00:01, 43.95it/s]
# Цикл по минибатчам:  33%|███▎      | 33/100 [00:00<00:01, 45.15it/s]
# Цикл по минибатчам:  38%|███▊      | 38/100 [00:00<00:01, 45.92it/s]
# Цикл по минибатчам:  43%|████▎     | 43/100 [00:00<00:01, 46.53it/s]
# Цикл по минибатчам:  48%|████▊     | 48/100 [00:01<00:01, 47.11it/s]
# Цикл по минибатчам:  53%|█████▎    | 53/100 [00:01<00:00, 47.58it/s]
# Цикл по минибатчам:  58%|█████▊    | 58/100 [00:01<00:00, 47.84it/s]
# Цикл по минибатчам:  63%|██████▎   | 63/100 [00:01<00:00, 47.88it/s]
# Цикл по минибатчам:  68%|██████▊   | 68/100 [00:01<00:00, 45.63it/s]
# Цикл по минибатчам:  73%|███████▎  | 73/100 [00:01<00:00, 44.50it/s]
# Цикл по минибатчам:  78%|███████▊  | 78/100 [00:01<00:00, 44.45it/s]
# Цикл по минибатчам:  83%|████████▎ | 83/100 [00:01<00:00, 45.43it/s]
# Цикл по минибатчам:  88%|████████▊ | 88/100 [00:01<00:00, 46.16it/s]
# Цикл по минибатчам:  94%|█████████▍| 94/100 [00:02<00:00, 47.54it/s]
# Цикл по минибатчам: 100%|██████████| 100/100 [00:02<00:00, 46.55it/s]
# Цикл по Эпохам:  20%|██        | 2/10 [00:34<02:18, 17.35s/it]
# Loader: valid. Accuracy: 0.9547
# Цикл по минибатчам:   0%|          | 0/600 [00:00<?, ?it/s]
# Цикл по минибатчам:   1%|          | 5/600 [00:00<00:13, 45.41it/s]
# Цикл по минибатчам:   2%|▏         | 10/600 [00:00<00:13, 44.77it/s]
# Цикл по минибатчам:   2%|▎         | 15/600 [00:00<00:15, 38.87it/s]
# Цикл по минибатчам:   3%|▎         | 19/600 [00:00<00:14, 39.15it/s]
# Цикл по минибатчам:   4%|▍         | 24/600 [00:00<00:14, 40.16it/s]
# Цикл по минибатчам:   5%|▍         | 29/600 [00:00<00:13, 42.20it/s]
# Цикл по минибатчам:   6%|▌         | 34/600 [00:00<00:12, 43.70it/s]
# Цикл по минибатчам:   6%|▋         | 39/600 [00:00<00:12, 44.50it/s]
# Цикл по минибатчам:   7%|▋         | 44/600 [00:01<00:12, 44.80it/s]
# Цикл по минибатчам:   8%|▊         | 49/600 [00:01<00:12, 44.99it/s]
# Цикл по минибатчам:   9%|▉         | 54/600 [00:01<00:12, 44.77it/s]
# Цикл по минибатчам:  10%|▉         | 59/600 [00:01<00:12, 42.12it/s]
# Цикл по минибатчам:  11%|█         | 64/600 [00:01<00:13, 40.68it/s]
# Цикл по минибатчам:  12%|█▏        | 69/600 [00:01<00:12, 42.18it/s]
# Цикл по минибатчам:  12%|█▏        | 74/600 [00:01<00:13, 40.27it/s]
# Цикл по минибатчам:  13%|█▎        | 79/600 [00:01<00:14, 36.23it/s]
# Цикл по минибатчам:  14%|█▍        | 83/600 [00:02<00:14, 34.85it/s]
# Цикл по минибатчам:  14%|█▍        | 87/600 [00:02<00:15, 34.04it/s]
# Цикл по минибатчам:  15%|█▌        | 91/600 [00:02<00:16, 31.36it/s]
# Цикл по минибатчам:  16%|█▌        | 95/600 [00:02<00:15, 31.80it/s]
# Цикл по минибатчам:  16%|█▋        | 99/600 [00:02<00:15, 31.34it/s]
# Цикл по минибатчам:  17%|█▋        | 103/600 [00:02<00:15, 32.25it/s]
# Цикл по минибатчам:  18%|█▊        | 107/600 [00:02<00:15, 32.83it/s]
# Цикл по минибатчам:  18%|█▊        | 111/600 [00:02<00:14, 33.39it/s]
# Цикл по минибатчам:  19%|█▉        | 115/600 [00:03<00:15, 32.00it/s]
# Цикл по минибатчам:  20%|█▉        | 119/600 [00:03<00:15, 31.03it/s]
# Цикл по минибатчам:  20%|██        | 123/600 [00:03<00:15, 30.30it/s]
# Цикл по минибатчам:  21%|██        | 127/600 [00:03<00:16, 29.02it/s]
# Цикл по минибатчам:  22%|██▏       | 130/600 [00:03<00:16, 28.13it/s]
# Цикл по минибатчам:  22%|██▏       | 133/600 [00:03<00:16, 27.47it/s]
# Цикл по минибатчам:  23%|██▎       | 136/600 [00:03<00:16, 27.98it/s]
# Цикл по минибатчам:  23%|██▎       | 139/600 [00:03<00:16, 28.33it/s]
# Цикл по минибатчам:  24%|██▎       | 142/600 [00:04<00:16, 28.55it/s]
# Цикл по минибатчам:  24%|██▍       | 145/600 [00:04<00:16, 28.08it/s]
# Цикл по минибатчам:  25%|██▍       | 148/600 [00:04<00:16, 27.32it/s]
# Цикл по минибатчам:  25%|██▌       | 151/600 [00:04<00:17, 25.84it/s]
# Цикл по минибатчам:  26%|██▌       | 156/600 [00:04<00:14, 31.09it/s]
# Цикл по минибатчам:  27%|██▋       | 160/600 [00:04<00:13, 32.84it/s]
# Цикл по минибатчам:  28%|██▊       | 165/600 [00:04<00:12, 36.17it/s]
# Цикл по минибатчам:  28%|██▊       | 170/600 [00:04<00:11, 38.80it/s]
# Цикл по минибатчам:  29%|██▉       | 175/600 [00:04<00:10, 40.63it/s]
# Цикл по минибатчам:  30%|███       | 180/600 [00:05<00:10, 41.91it/s]
# Цикл по минибатчам:  31%|███       | 185/600 [00:05<00:09, 42.59it/s]
# Цикл по минибатчам:  32%|███▏      | 190/600 [00:05<00:10, 40.65it/s]
# Цикл по минибатчам:  32%|███▎      | 195/600 [00:05<00:09, 40.95it/s]
# Цикл по минибатчам:  33%|███▎      | 200/600 [00:05<00:09, 41.95it/s]
# Цикл по минибатчам:  34%|███▍      | 205/600 [00:05<00:09, 41.07it/s]
# Цикл по минибатчам:  35%|███▌      | 210/600 [00:05<00:09, 42.33it/s]
# Цикл по минибатчам:  36%|███▌      | 215/600 [00:05<00:08, 43.32it/s]
# Цикл по минибатчам:  37%|███▋      | 220/600 [00:06<00:08, 43.79it/s]
# Цикл по минибатчам:  38%|███▊      | 225/600 [00:06<00:08, 43.74it/s]
# Цикл по минибатчам:  38%|███▊      | 230/600 [00:06<00:08, 44.19it/s]
# Цикл по минибатчам:  39%|███▉      | 235/600 [00:06<00:08, 41.51it/s]
# Цикл по минибатчам:  40%|████      | 240/600 [00:06<00:08, 42.14it/s]
# Цикл по минибатчам:  41%|████      | 245/600 [00:06<00:08, 42.79it/s]
# Цикл по минибатчам:  42%|████▏     | 250/600 [00:06<00:08, 42.35it/s]
# Цикл по минибатчам:  42%|████▎     | 255/600 [00:06<00:07, 43.75it/s]
# Цикл по минибатчам:  43%|████▎     | 260/600 [00:06<00:07, 44.47it/s]
# Цикл по минибатчам:  44%|████▍     | 265/600 [00:07<00:07, 45.14it/s]
# Цикл по минибатчам:  45%|████▌     | 270/600 [00:07<00:07, 44.77it/s]
# Цикл по минибатчам:  46%|████▌     | 275/600 [00:07<00:07, 43.79it/s]
# Цикл по минибатчам:  47%|████▋     | 280/600 [00:07<00:07, 41.78it/s]
# Цикл по минибатчам:  48%|████▊     | 285/600 [00:07<00:07, 42.81it/s]
# Цикл по минибатчам:  48%|████▊     | 290/600 [00:07<00:07, 43.63it/s]
# Цикл по минибатчам:  49%|████▉     | 295/600 [00:07<00:07, 42.64it/s]
# Цикл по минибатчам:  50%|█████     | 300/600 [00:07<00:06, 43.77it/s]
# Цикл по минибатчам:  51%|█████     | 305/600 [00:07<00:06, 44.26it/s]
# Цикл по минибатчам:  52%|█████▏    | 310/600 [00:08<00:06, 44.57it/s]
# Цикл по минибатчам:  52%|█████▎    | 315/600 [00:08<00:06, 44.73it/s]
# Цикл по минибатчам:  53%|█████▎    | 320/600 [00:08<00:06, 42.01it/s]
# Цикл по минибатчам:  54%|█████▍    | 325/600 [00:08<00:06, 41.96it/s]
# Цикл по минибатчам:  55%|█████▌    | 330/600 [00:08<00:06, 42.81it/s]
# Цикл по минибатчам:  56%|█████▌    | 335/600 [00:08<00:06, 42.78it/s]
# Цикл по минибатчам:  57%|█████▋    | 340/600 [00:08<00:06, 41.89it/s]
# Цикл по минибатчам:  57%|█████▊    | 345/600 [00:08<00:05, 43.02it/s]
# Цикл по минибатчам:  58%|█████▊    | 350/600 [00:09<00:05, 43.74it/s]
# Цикл по минибатчам:  59%|█████▉    | 355/600 [00:09<00:05, 44.00it/s]
# Цикл по минибатчам:  60%|██████    | 360/600 [00:09<00:05, 43.90it/s]
# Цикл по минибатчам:  61%|██████    | 365/600 [00:09<00:05, 41.50it/s]
# Цикл по минибатчам:  62%|██████▏   | 370/600 [00:09<00:05, 42.05it/s]
# Цикл по минибатчам:  62%|██████▎   | 375/600 [00:09<00:05, 42.31it/s]
# Цикл по минибатчам:  63%|██████▎   | 380/600 [00:09<00:05, 41.40it/s]
# Цикл по минибатчам:  64%|██████▍   | 385/600 [00:09<00:05, 42.60it/s]
# Цикл по минибатчам:  65%|██████▌   | 390/600 [00:09<00:04, 43.23it/s]
# Цикл по минибатчам:  66%|██████▌   | 395/600 [00:10<00:04, 44.03it/s]
# Цикл по минибатчам:  67%|██████▋   | 400/600 [00:10<00:04, 44.35it/s]
# Цикл по минибатчам:  68%|██████▊   | 405/600 [00:10<00:04, 41.69it/s]
# Цикл по минибатчам:  68%|██████▊   | 410/600 [00:10<00:04, 41.41it/s]
# Цикл по минибатчам:  69%|██████▉   | 415/600 [00:10<00:04, 41.89it/s]
# Цикл по минибатчам:  70%|███████   | 420/600 [00:10<00:04, 42.33it/s]
# Цикл по минибатчам:  71%|███████   | 425/600 [00:10<00:04, 41.62it/s]
# Цикл по минибатчам:  72%|███████▏  | 430/600 [00:10<00:03, 42.92it/s]
# Цикл по минибатчам:  72%|███████▎  | 435/600 [00:11<00:03, 43.83it/s]
# Цикл по минибатчам:  73%|███████▎  | 440/600 [00:11<00:03, 44.00it/s]
# Цикл по минибатчам:  74%|███████▍  | 445/600 [00:11<00:03, 43.68it/s]
# Цикл по минибатчам:  75%|███████▌  | 450/600 [00:11<00:03, 41.49it/s]
# Цикл по минибатчам:  76%|███████▌  | 455/600 [00:11<00:03, 42.07it/s]
# Цикл по минибатчам:  77%|███████▋  | 460/600 [00:11<00:03, 42.37it/s]
# Цикл по минибатчам:  78%|███████▊  | 465/600 [00:11<00:03, 42.60it/s]
# Цикл по минибатчам:  78%|███████▊  | 470/600 [00:11<00:03, 42.06it/s]
# Цикл по минибатчам:  79%|███████▉  | 475/600 [00:11<00:02, 42.94it/s]
# Цикл по минибатчам:  80%|████████  | 480/600 [00:12<00:02, 43.59it/s]
# Цикл по минибатчам:  81%|████████  | 485/600 [00:12<00:02, 43.29it/s]
# Цикл по минибатчам:  82%|████████▏ | 490/600 [00:12<00:02, 41.31it/s]
# Цикл по минибатчам:  82%|████████▎ | 495/600 [00:12<00:02, 41.33it/s]
# Цикл по минибатчам:  83%|████████▎ | 500/600 [00:12<00:02, 41.94it/s]
# Цикл по минибатчам:  84%|████████▍ | 505/600 [00:12<00:02, 42.23it/s]
# Цикл по минибатчам:  85%|████████▌ | 510/600 [00:12<00:02, 43.33it/s]
# Цикл по минибатчам:  86%|████████▌ | 515/600 [00:12<00:01, 42.59it/s]
# Цикл по минибатчам:  87%|████████▋ | 520/600 [00:13<00:01, 43.01it/s]
# Цикл по минибатчам:  88%|████████▊ | 525/600 [00:13<00:01, 43.41it/s]
# Цикл по минибатчам:  88%|████████▊ | 530/600 [00:13<00:01, 43.92it/s]
# Цикл по минибатчам:  89%|████████▉ | 535/600 [00:13<00:01, 41.73it/s]
# Цикл по минибатчам:  90%|█████████ | 540/600 [00:13<00:01, 42.56it/s]
# Цикл по минибатчам:  91%|█████████ | 545/600 [00:13<00:01, 43.38it/s]
# Цикл по минибатчам:  92%|█████████▏| 550/600 [00:13<00:01, 43.76it/s]
# Цикл по минибатчам:  92%|█████████▎| 555/600 [00:13<00:01, 43.93it/s]
# Цикл по минибатчам:  93%|█████████▎| 560/600 [00:13<00:00, 43.37it/s]
# Цикл по минибатчам:  94%|█████████▍| 565/600 [00:14<00:00, 44.25it/s]
# Цикл по минибатчам:  95%|█████████▌| 570/600 [00:14<00:00, 43.79it/s]
# Цикл по минибатчам:  96%|█████████▌| 575/600 [00:14<00:00, 42.63it/s]
# Цикл по минибатчам:  97%|█████████▋| 580/600 [00:14<00:00, 39.88it/s]
# Цикл по минибатчам:  98%|█████████▊| 585/600 [00:14<00:00, 34.92it/s]
# Цикл по минибатчам:  98%|█████████▊| 589/600 [00:14<00:00, 33.71it/s]
# Цикл по минибатчам:  99%|█████████▉| 593/600 [00:14<00:00, 32.60it/s]
# Цикл по минибатчам: 100%|██████████| 600/600 [00:15<00:00, 39.73it/s]
# Epoch: 3
# Loader: train. Accuracy: 0.96125
# Цикл по минибатчам:   0%|          | 0/100 [00:00<?, ?it/s]
# Цикл по минибатчам:   4%|▍         | 4/100 [00:00<00:02, 34.06it/s]
# Цикл по минибатчам:   8%|▊         | 8/100 [00:00<00:02, 31.25it/s]
# Цикл по минибатчам:  12%|█▏        | 12/100 [00:00<00:02, 33.09it/s]
# Цикл по минибатчам:  16%|█▌        | 16/100 [00:00<00:02, 33.75it/s]
# Цикл по минибатчам:  20%|██        | 20/100 [00:00<00:02, 32.54it/s]
# Цикл по минибатчам:  24%|██▍       | 24/100 [00:00<00:02, 32.32it/s]
# Цикл по минибатчам:  28%|██▊       | 28/100 [00:00<00:02, 31.22it/s]
# Цикл по минибатчам:  32%|███▏      | 32/100 [00:01<00:02, 30.36it/s]
# Цикл по минибатчам:  36%|███▌      | 36/100 [00:01<00:02, 29.77it/s]
# Цикл по минибатчам:  39%|███▉      | 39/100 [00:01<00:02, 28.12it/s]
# Цикл по минибатчам:  43%|████▎     | 43/100 [00:01<00:01, 29.19it/s]
# Цикл по минибатчам:  46%|████▌     | 46/100 [00:01<00:01, 29.20it/s]
# Цикл по минибатчам:  50%|█████     | 50/100 [00:01<00:01, 29.96it/s]
# Цикл по минибатчам:  54%|█████▍    | 54/100 [00:01<00:01, 30.92it/s]
# Цикл по минибатчам:  58%|█████▊    | 58/100 [00:01<00:01, 29.07it/s]
# Цикл по минибатчам:  62%|██████▏   | 62/100 [00:02<00:01, 30.40it/s]
# Цикл по минибатчам:  67%|██████▋   | 67/100 [00:02<00:00, 33.95it/s]
# Цикл по минибатчам:  71%|███████   | 71/100 [00:02<00:00, 34.83it/s]
# Цикл по минибатчам:  76%|███████▌  | 76/100 [00:02<00:00, 38.41it/s]
# Цикл по минибатчам:  81%|████████  | 81/100 [00:02<00:00, 41.07it/s]
# Цикл по минибатчам:  86%|████████▌ | 86/100 [00:02<00:00, 42.31it/s]
# Цикл по минибатчам:  91%|█████████ | 91/100 [00:02<00:00, 44.41it/s]
# Цикл по минибатчам: 100%|██████████| 100/100 [00:02<00:00, 35.03it/s]
# Цикл по Эпохам:  30%|███       | 3/10 [00:52<02:03, 17.64s/it]
# Loader: valid. Accuracy: 0.961
# Цикл по минибатчам:   0%|          | 0/600 [00:00<?, ?it/s]
# Цикл по минибатчам:   1%|          | 5/600 [00:00<00:13, 43.84it/s]
# Цикл по минибатчам:   2%|▏         | 10/600 [00:00<00:13, 44.02it/s]
# Цикл по минибатчам:   2%|▎         | 15/600 [00:00<00:14, 39.32it/s]
# Цикл по минибатчам:   3%|▎         | 20/600 [00:00<00:14, 40.31it/s]
# Цикл по минибатчам:   4%|▍         | 25/600 [00:00<00:13, 41.35it/s]
# Цикл по минибатчам:   5%|▌         | 30/600 [00:00<00:13, 41.94it/s]
# Цикл по минибатчам:   6%|▌         | 35/600 [00:00<00:13, 43.36it/s]
# Цикл по минибатчам:   7%|▋         | 40/600 [00:00<00:12, 44.08it/s]
# Цикл по минибатчам:   8%|▊         | 45/600 [00:01<00:12, 44.35it/s]
# Цикл по минибатчам:   8%|▊         | 50/600 [00:01<00:12, 42.68it/s]
# Цикл по минибатчам:   9%|▉         | 55/600 [00:01<00:13, 41.69it/s]
# Цикл по минибатчам:  10%|█         | 60/600 [00:01<00:13, 40.57it/s]
# Цикл по минибатчам:  11%|█         | 65/600 [00:01<00:12, 41.47it/s]
# Цикл по минибатчам:  12%|█▏        | 70/600 [00:01<00:12, 42.71it/s]
# Цикл по минибатчам:  12%|█▎        | 75/600 [00:01<00:12, 43.52it/s]
# Цикл по минибатчам:  13%|█▎        | 80/600 [00:01<00:11, 44.23it/s]
# Цикл по минибатчам:  14%|█▍        | 85/600 [00:01<00:11, 44.49it/s]
# Цикл по минибатчам:  15%|█▌        | 90/600 [00:02<00:11, 43.47it/s]
# Цикл по минибатчам:  16%|█▌        | 95/600 [00:02<00:11, 43.63it/s]
# Цикл по минибатчам:  17%|█▋        | 100/600 [00:02<00:12, 41.06it/s]
# Цикл по минибатчам:  18%|█▊        | 105/600 [00:02<00:11, 41.89it/s]
# Цикл по минибатчам:  18%|█▊        | 110/600 [00:02<00:11, 42.36it/s]
# Цикл по минибатчам:  19%|█▉        | 115/600 [00:02<00:12, 39.40it/s]
# Цикл по минибатчам:  20%|██        | 120/600 [00:02<00:11, 41.06it/s]
# Цикл по минибатчам:  21%|██        | 125/600 [00:02<00:11, 42.21it/s]
# Цикл по минибатчам:  22%|██▏       | 130/600 [00:03<00:10, 43.08it/s]
# Цикл по минибатчам:  22%|██▎       | 135/600 [00:03<00:11, 42.03it/s]
# Цикл по минибатчам:  23%|██▎       | 140/600 [00:03<00:11, 40.37it/s]
# Цикл по минибатчам:  24%|██▍       | 145/600 [00:03<00:11, 40.71it/s]
# Цикл по минибатчам:  25%|██▌       | 150/600 [00:03<00:10, 41.07it/s]
# Цикл по минибатчам:  26%|██▌       | 155/600 [00:03<00:10, 41.39it/s]
# Цикл по минибатчам:  27%|██▋       | 160/600 [00:03<00:10, 42.75it/s]
# Цикл по минибатчам:  28%|██▊       | 165/600 [00:03<00:09, 43.82it/s]
# Цикл по минибатчам:  28%|██▊       | 170/600 [00:04<00:09, 44.45it/s]
# Цикл по минибатчам:  29%|██▉       | 175/600 [00:04<00:09, 44.66it/s]
# Цикл по минибатчам:  30%|███       | 180/600 [00:04<00:09, 43.03it/s]
# Цикл по минибатчам:  31%|███       | 185/600 [00:04<00:10, 40.52it/s]
# Цикл по минибатчам:  32%|███▏      | 190/600 [00:04<00:09, 41.90it/s]
# Цикл по минибатчам:  32%|███▎      | 195/600 [00:04<00:09, 42.52it/s]
# Цикл по минибатчам:  33%|███▎      | 200/600 [00:04<00:09, 42.85it/s]
# Цикл по минибатчам:  34%|███▍      | 205/600 [00:04<00:09, 42.96it/s]
# Цикл по минибатчам:  35%|███▌      | 210/600 [00:04<00:08, 43.44it/s]
# Цикл по минибатчам:  36%|███▌      | 215/600 [00:05<00:08, 44.24it/s]
# Цикл по минибатчам:  37%|███▋      | 220/600 [00:05<00:08, 42.69it/s]
# Цикл по минибатчам:  38%|███▊      | 225/600 [00:05<00:09, 41.45it/s]
# Цикл по минибатчам:  38%|███▊      | 230/600 [00:05<00:09, 41.10it/s]
# Цикл по минибатчам:  39%|███▉      | 235/600 [00:05<00:08, 42.35it/s]
# Цикл по минибатчам:  40%|████      | 240/600 [00:05<00:08, 42.93it/s]
# Цикл по минибатчам:  41%|████      | 245/600 [00:05<00:08, 43.72it/s]
# Цикл по минибатчам:  42%|████▏     | 250/600 [00:05<00:07, 44.71it/s]
# Цикл по минибатчам:  42%|████▎     | 255/600 [00:05<00:07, 45.17it/s]
# Цикл по минибатчам:  43%|████▎     | 260/600 [00:06<00:07, 45.63it/s]
# Цикл по минибатчам:  44%|████▍     | 265/600 [00:06<00:07, 43.22it/s]
# Цикл по минибатчам:  45%|████▌     | 270/600 [00:06<00:08, 40.39it/s]
# Цикл по минибатчам:  46%|████▌     | 275/600 [00:06<00:07, 41.68it/s]
# Цикл по минибатчам:  47%|████▋     | 280/600 [00:06<00:07, 41.48it/s]
# Цикл по минибатчам:  48%|████▊     | 285/600 [00:06<00:07, 41.76it/s]
# Цикл по минибатчам:  48%|████▊     | 290/600 [00:06<00:07, 41.47it/s]
# Цикл по минибатчам:  49%|████▉     | 295/600 [00:06<00:07, 40.71it/s]
# Цикл по минибатчам:  50%|█████     | 300/600 [00:07<00:07, 42.13it/s]
# Цикл по минибатчам:  51%|█████     | 305/600 [00:07<00:06, 42.74it/s]
# Цикл по минибатчам:  52%|█████▏    | 310/600 [00:07<00:07, 39.87it/s]
# Цикл по минибатчам:  52%|█████▎    | 315/600 [00:07<00:07, 39.82it/s]
# Цикл по минибатчам:  53%|█████▎    | 320/600 [00:07<00:06, 41.21it/s]
# Цикл по минибатчам:  54%|█████▍    | 325/600 [00:07<00:06, 42.63it/s]
# Цикл по минибатчам:  55%|█████▌    | 330/600 [00:07<00:06, 43.53it/s]
# Цикл по минибатчам:  56%|█████▌    | 335/600 [00:07<00:06, 44.10it/s]
# Цикл по минибатчам:  57%|█████▋    | 340/600 [00:08<00:05, 44.50it/s]
# Цикл по минибатчам:  57%|█████▊    | 345/600 [00:08<00:05, 45.01it/s]
# Цикл по минибатчам:  58%|█████▊    | 350/600 [00:08<00:05, 44.94it/s]
# Цикл по минибатчам:  59%|█████▉    | 355/600 [00:08<00:06, 40.59it/s]
# Цикл по минибатчам:  60%|██████    | 360/600 [00:08<00:06, 39.24it/s]
# Цикл по минибатчам:  61%|██████    | 364/600 [00:08<00:06, 38.83it/s]
# Цикл по минибатчам:  62%|██████▏   | 369/600 [00:08<00:05, 40.12it/s]
# Цикл по минибатчам:  62%|██████▏   | 374/600 [00:08<00:05, 41.89it/s]
# Цикл по минибатчам:  63%|██████▎   | 379/600 [00:08<00:05, 42.59it/s]
# Цикл по минибатчам:  64%|██████▍   | 384/600 [00:09<00:05, 43.19it/s]
# Цикл по минибатчам:  65%|██████▍   | 389/600 [00:09<00:05, 38.24it/s]
# Цикл по минибатчам:  66%|██████▌   | 393/600 [00:09<00:06, 33.09it/s]
# Цикл по минибатчам:  66%|██████▌   | 397/600 [00:09<00:06, 33.03it/s]
# Цикл по минибатчам:  67%|██████▋   | 401/600 [00:09<00:06, 32.34it/s]
# Цикл по минибатчам:  68%|██████▊   | 405/600 [00:09<00:05, 32.73it/s]
# Цикл по минибатчам:  68%|██████▊   | 409/600 [00:09<00:05, 33.24it/s]
# Цикл по минибатчам:  69%|██████▉   | 413/600 [00:10<00:05, 33.15it/s]
# Цикл по минибатчам:  70%|██████▉   | 417/600 [00:10<00:05, 33.70it/s]
# Цикл по минибатчам:  70%|███████   | 421/600 [00:10<00:07, 24.84it/s]
# Цикл по минибатчам:  71%|███████   | 424/600 [00:10<00:11, 15.04it/s]
# Цикл по минибатчам:  71%|███████   | 427/600 [00:11<00:14, 12.24it/s]
# Цикл по минибатчам:  72%|███████▏  | 430/600 [00:11<00:12, 14.12it/s]
# Цикл по минибатчам:  72%|███████▏  | 433/600 [00:11<00:10, 16.09it/s]
# Цикл по минибатчам:  73%|███████▎  | 436/600 [00:11<00:08, 18.39it/s]
# Цикл по минибатчам:  73%|███████▎  | 439/600 [00:11<00:07, 20.51it/s]
# Цикл по минибатчам:  74%|███████▎  | 442/600 [00:11<00:07, 22.33it/s]
# Цикл по минибатчам:  74%|███████▍  | 445/600 [00:11<00:06, 24.14it/s]
# Цикл по минибатчам:  75%|███████▍  | 448/600 [00:11<00:05, 25.44it/s]
# Цикл по минибатчам:  75%|███████▌  | 451/600 [00:12<00:05, 26.25it/s]
# Цикл по минибатчам:  76%|███████▌  | 454/600 [00:12<00:05, 26.80it/s]
# Цикл по минибатчам:  76%|███████▌  | 457/600 [00:12<00:05, 26.11it/s]
# Цикл по минибатчам:  77%|███████▋  | 460/600 [00:12<00:05, 25.71it/s]
# Цикл по минибатчам:  77%|███████▋  | 464/600 [00:12<00:04, 29.31it/s]
# Цикл по минибатчам:  78%|███████▊  | 469/600 [00:12<00:03, 33.01it/s]
# Цикл по минибатчам:  79%|███████▉  | 474/600 [00:12<00:03, 36.06it/s]
# Цикл по минибатчам:  80%|███████▉  | 479/600 [00:12<00:03, 38.41it/s]
# Цикл по минибатчам:  81%|████████  | 484/600 [00:12<00:02, 40.18it/s]
# Цикл по минибатчам:  82%|████████▏ | 489/600 [00:13<00:02, 41.88it/s]
# Цикл по минибатчам:  82%|████████▏ | 494/600 [00:13<00:02, 42.64it/s]
# Цикл по минибатчам:  83%|████████▎ | 499/600 [00:13<00:02, 39.49it/s]
# Цикл по минибатчам:  84%|████████▍ | 504/600 [00:13<00:02, 39.49it/s]
# Цикл по минибатчам:  85%|████████▍ | 509/600 [00:13<00:02, 40.51it/s]
# Цикл по минибатчам:  86%|████████▌ | 514/600 [00:13<00:02, 40.95it/s]
# Цикл по минибатчам:  86%|████████▋ | 519/600 [00:13<00:01, 41.79it/s]
# Цикл по минибатчам:  87%|████████▋ | 524/600 [00:13<00:01, 42.24it/s]
# Цикл по минибатчам:  88%|████████▊ | 529/600 [00:14<00:01, 43.14it/s]
# Цикл по минибатчам:  89%|████████▉ | 534/600 [00:14<00:01, 43.61it/s]
# Цикл по минибатчам:  90%|████████▉ | 539/600 [00:14<00:01, 41.32it/s]
# Цикл по минибатчам:  91%|█████████ | 544/600 [00:14<00:01, 40.77it/s]
# Цикл по минибатчам:  92%|█████████▏| 549/600 [00:14<00:01, 40.91it/s]
# Цикл по минибатчам:  92%|█████████▏| 554/600 [00:14<00:01, 41.70it/s]
# Цикл по минибатчам:  93%|█████████▎| 559/600 [00:14<00:00, 41.97it/s]
# Цикл по минибатчам:  94%|█████████▍| 564/600 [00:14<00:00, 43.05it/s]
# Цикл по минибатчам:  95%|█████████▍| 569/600 [00:15<00:00, 43.50it/s]
# Цикл по минибатчам:  96%|█████████▌| 574/600 [00:15<00:00, 43.39it/s]
# Цикл по минибатчам:  96%|█████████▋| 579/600 [00:15<00:00, 43.62it/s]
# Цикл по минибатчам:  97%|█████████▋| 584/600 [00:15<00:00, 40.56it/s]
# Цикл по минибатчам:  98%|█████████▊| 589/600 [00:15<00:00, 41.80it/s]
# Цикл по минибатчам:  99%|█████████▉| 594/600 [00:15<00:00, 41.39it/s]
# Цикл по минибатчам: 100%|██████████| 600/600 [00:15<00:00, 38.06it/s]
# Epoch: 4
# Loader: train. Accuracy: 0.9698833333333333
# Цикл по минибатчам:   0%|          | 0/100 [00:00<?, ?it/s]
# Цикл по минибатчам:   6%|▌         | 6/100 [00:00<00:01, 50.73it/s]
# Цикл по минибатчам:  12%|█▏        | 12/100 [00:00<00:01, 50.37it/s]
# Цикл по минибатчам:  18%|█▊        | 18/100 [00:00<00:01, 50.27it/s]
# Цикл по минибатчам:  24%|██▍       | 24/100 [00:00<00:01, 50.02it/s]
# Цикл по минибатчам:  30%|███       | 30/100 [00:00<00:01, 44.82it/s]
# Цикл по минибатчам:  35%|███▌      | 35/100 [00:00<00:01, 45.35it/s]
# Цикл по минибатчам:  40%|████      | 40/100 [00:00<00:01, 44.19it/s]
# Цикл по минибатчам:  45%|████▌     | 45/100 [00:00<00:01, 45.64it/s]
# Цикл по минибатчам:  51%|█████     | 51/100 [00:01<00:01, 47.29it/s]
# Цикл по минибатчам:  56%|█████▌    | 56/100 [00:01<00:00, 47.62it/s]
# Цикл по минибатчам:  62%|██████▏   | 62/100 [00:01<00:00, 48.53it/s]
# Цикл по минибатчам:  67%|██████▋   | 67/100 [00:01<00:00, 48.48it/s]
# Цикл по минибатчам:  72%|███████▏  | 72/100 [00:01<00:00, 46.51it/s]
# Цикл по минибатчам:  77%|███████▋  | 77/100 [00:01<00:00, 44.91it/s]
# Цикл по минибатчам:  82%|████████▏ | 82/100 [00:01<00:00, 45.88it/s]
# Цикл по минибатчам:  87%|████████▋ | 87/100 [00:01<00:00, 44.41it/s]
# Цикл по минибатчам:  92%|█████████▏| 92/100 [00:01<00:00, 45.11it/s]
# Цикл по минибатчам: 100%|██████████| 100/100 [00:02<00:00, 46.63it/s]
# Цикл по Эпохам:  40%|████      | 4/10 [01:10<01:46, 17.75s/it]
# Loader: valid. Accuracy: 0.9641
# Цикл по минибатчам:   0%|          | 0/600 [00:00<?, ?it/s]
# Цикл по минибатчам:   1%|          | 5/600 [00:00<00:12, 45.77it/s]
# Цикл по минибатчам:   2%|▏         | 10/600 [00:00<00:13, 44.57it/s]
# Цикл по минибатчам:   2%|▎         | 15/600 [00:00<00:13, 42.86it/s]
# Цикл по минибатчам:   3%|▎         | 20/600 [00:00<00:14, 39.13it/s]
# Цикл по минибатчам:   4%|▍         | 25/600 [00:00<00:13, 41.44it/s]
# Цикл по минибатчам:   5%|▌         | 30/600 [00:00<00:13, 41.01it/s]
# Цикл по минибатчам:   6%|▌         | 35/600 [00:00<00:13, 42.50it/s]
# Цикл по минибатчам:   7%|▋         | 40/600 [00:00<00:12, 43.77it/s]
# Цикл по минибатчам:   8%|▊         | 45/600 [00:01<00:12, 44.30it/s]
# Цикл по минибатчам:   8%|▊         | 50/600 [00:01<00:12, 44.84it/s]
# Цикл по минибатчам:   9%|▉         | 55/600 [00:01<00:12, 45.11it/s]
# Цикл по минибатчам:  10%|█         | 60/600 [00:01<00:12, 42.15it/s]
# Цикл по минибатчам:  11%|█         | 65/600 [00:01<00:12, 41.55it/s]
# Цикл по минибатчам:  12%|█▏        | 70/600 [00:01<00:12, 42.18it/s]
# Цикл по минибатчам:  12%|█▎        | 75/600 [00:01<00:12, 41.76it/s]
# Цикл по минибатчам:  13%|█▎        | 80/600 [00:01<00:12, 43.05it/s]
# Цикл по минибатчам:  14%|█▍        | 85/600 [00:01<00:11, 44.02it/s]
# Цикл по минибатчам:  15%|█▌        | 90/600 [00:02<00:11, 44.45it/s]
# Цикл по минибатчам:  16%|█▌        | 95/600 [00:02<00:11, 45.19it/s]
# Цикл по минибатчам:  17%|█▋        | 100/600 [00:02<00:11, 45.16it/s]
# Цикл по минибатчам:  18%|█▊        | 105/600 [00:02<00:11, 41.92it/s]
# Цикл по минибатчам:  18%|█▊        | 110/600 [00:02<00:11, 42.86it/s]
# Цикл по минибатчам:  19%|█▉        | 115/600 [00:02<00:11, 43.73it/s]
# Цикл по минибатчам:  20%|██        | 120/600 [00:02<00:11, 42.29it/s]
# Цикл по минибатчам:  21%|██        | 125/600 [00:02<00:11, 43.05it/s]
# Цикл по минибатчам:  22%|██▏       | 130/600 [00:03<00:10, 43.48it/s]
# Цикл по минибатчам:  22%|██▎       | 135/600 [00:03<00:10, 44.28it/s]
# Цикл по минибатчам:  23%|██▎       | 140/600 [00:03<00:10, 44.52it/s]
# Цикл по минибатчам:  24%|██▍       | 145/600 [00:03<00:10, 43.29it/s]
# Цикл по минибатчам:  25%|██▌       | 150/600 [00:03<00:11, 40.63it/s]
# Цикл по минибатчам:  26%|██▌       | 155/600 [00:03<00:10, 41.73it/s]
# Цикл по минибатчам:  27%|██▋       | 160/600 [00:03<00:10, 42.24it/s]
# Цикл по минибатчам:  28%|██▊       | 165/600 [00:03<00:10, 41.57it/s]
# Цикл по минибатчам:  28%|██▊       | 170/600 [00:03<00:10, 42.66it/s]
# Цикл по минибатчам:  29%|██▉       | 175/600 [00:04<00:09, 43.24it/s]
# Цикл по минибатчам:  30%|███       | 180/600 [00:04<00:09, 43.74it/s]
# Цикл по минибатчам:  31%|███       | 185/600 [00:04<00:09, 44.16it/s]
# Цикл по минибатчам:  32%|███▏      | 190/600 [00:04<00:09, 41.08it/s]
# Цикл по минибатчам:  32%|███▎      | 195/600 [00:04<00:10, 36.86it/s]
# Цикл по минибатчам:  33%|███▎      | 199/600 [00:04<00:11, 34.40it/s]
# Цикл по минибатчам:  34%|███▍      | 203/600 [00:04<00:11, 33.26it/s]
# Цикл по минибатчам:  34%|███▍      | 207/600 [00:05<00:11, 32.94it/s]
# Цикл по минибатчам:  35%|███▌      | 211/600 [00:05<00:11, 32.91it/s]
# Цикл по минибатчам:  36%|███▌      | 215/600 [00:05<00:11, 33.08it/s]
# Цикл по минибатчам:  36%|███▋      | 219/600 [00:05<00:12, 31.64it/s]
# Цикл по минибатчам:  37%|███▋      | 223/600 [00:05<00:11, 31.48it/s]
# Цикл по минибатчам:  38%|███▊      | 227/600 [00:05<00:11, 31.56it/s]
# Цикл по минибатчам:  38%|███▊      | 231/600 [00:05<00:11, 31.83it/s]
# Цикл по минибатчам:  39%|███▉      | 235/600 [00:05<00:12, 29.68it/s]
# Цикл по минибатчам:  40%|███▉      | 239/600 [00:06<00:12, 29.86it/s]
# Цикл по минибатчам:  40%|████      | 243/600 [00:06<00:12, 29.65it/s]
# Цикл по минибатчам:  41%|████      | 246/600 [00:06<00:12, 28.90it/s]
# Цикл по минибатчам:  42%|████▏     | 249/600 [00:06<00:12, 27.09it/s]
# Цикл по минибатчам:  42%|████▏     | 252/600 [00:06<00:13, 26.34it/s]
# Цикл по минибатчам:  42%|████▎     | 255/600 [00:06<00:12, 26.94it/s]
# Цикл по минибатчам:  43%|████▎     | 258/600 [00:06<00:13, 25.94it/s]
# Цикл по минибатчам:  44%|████▎     | 261/600 [00:06<00:13, 25.63it/s]
# Цикл по минибатчам:  44%|████▍     | 264/600 [00:07<00:12, 26.52it/s]
# Цикл по минибатчам:  45%|████▍     | 269/600 [00:07<00:10, 32.05it/s]
# Цикл по минибатчам:  46%|████▌     | 274/600 [00:07<00:09, 36.07it/s]
# Цикл по минибатчам:  46%|████▋     | 279/600 [00:07<00:08, 38.77it/s]
# Цикл по минибатчам:  47%|████▋     | 283/600 [00:07<00:08, 37.55it/s]
# Цикл по минибатчам:  48%|████▊     | 288/600 [00:07<00:07, 40.15it/s]
# Цикл по минибатчам:  49%|████▉     | 293/600 [00:07<00:07, 41.11it/s]
# Цикл по минибатчам:  50%|████▉     | 298/600 [00:07<00:07, 42.18it/s]
# Цикл по минибатчам:  50%|█████     | 303/600 [00:07<00:06, 43.29it/s]
# Цикл по минибатчам:  51%|█████▏    | 308/600 [00:08<00:06, 42.44it/s]
# Цикл по минибатчам:  52%|█████▏    | 313/600 [00:08<00:06, 43.45it/s]
# Цикл по минибатчам:  53%|█████▎    | 318/600 [00:08<00:06, 43.62it/s]
# Цикл по минибатчам:  54%|█████▍    | 323/600 [00:08<00:06, 43.59it/s]
# Цикл по минибатчам:  55%|█████▍    | 328/600 [00:08<00:06, 41.11it/s]
# Цикл по минибатчам:  56%|█████▌    | 333/600 [00:08<00:06, 42.24it/s]
# Цикл по минибатчам:  56%|█████▋    | 338/600 [00:08<00:06, 43.18it/s]
# Цикл по минибатчам:  57%|█████▋    | 343/600 [00:08<00:05, 43.13it/s]
# Цикл по минибатчам:  58%|█████▊    | 348/600 [00:08<00:05, 42.88it/s]
# Цикл по минибатчам:  59%|█████▉    | 353/600 [00:09<00:05, 43.84it/s]
# Цикл по минибатчам:  60%|█████▉    | 358/600 [00:09<00:05, 44.57it/s]
# Цикл по минибатчам:  60%|██████    | 363/600 [00:09<00:05, 44.81it/s]
# Цикл по минибатчам:  61%|██████▏   | 368/600 [00:09<00:05, 42.03it/s]
# Цикл по минибатчам:  62%|██████▏   | 373/600 [00:09<00:05, 41.92it/s]
# Цикл по минибатчам:  63%|██████▎   | 378/600 [00:09<00:05, 42.96it/s]
# Цикл по минибатчам:  64%|██████▍   | 383/600 [00:09<00:05, 42.91it/s]
# Цикл по минибатчам:  65%|██████▍   | 388/600 [00:09<00:04, 43.55it/s]
# ...
# Цикл по минибатчам:  60%|██████    | 363/600 [00:08<00:05, 43.74it/s]
# Цикл по минибатчам:  61%|██████▏   | 368/600 [00:08<00:05, 42.36it/s]
# Цикл по минибатчам:  62%|██████▏   | 373/600 [00:08<00:05, 41.19it/s]
# Цикл по минибатчам:  63%|██████▎   | 378/600 [00:08<00:05, 42.26it/s]
# Цикл по минибатчам:  64%|██████▍   | 383/600 [00:09<00:05, 42.45it/s]
# Цикл по минибатчам:  65%|██████▍   | 388/600 [00:09<00:04, 42.80it/s]
# Цикл по минибатчам:  66%|██████▌   | 393/600 [00:09<00:04, 43.14it/s]
# Цикл по минибатчам:  66%|██████▋   | 398/600 [00:09<00:04, 43.75it/s]
# Цикл по минибатчам:  67%|██████▋   | 403/600 [00:09<00:04, 44.05it/s]
# Цикл по минибатчам:  68%|██████▊   | 408/600 [00:09<00:04, 44.58it/s]
# Цикл по минибатчам:  69%|██████▉   | 413/600 [00:09<00:04, 43.16it/s]
# Цикл по минибатчам:  70%|██████▉   | 418/600 [00:09<00:04, 42.25it/s]
# Цикл по минибатчам:  70%|███████   | 423/600 [00:09<00:04, 43.13it/s]
# Цикл по минибатчам:  71%|███████▏  | 428/600 [00:10<00:04, 38.26it/s]
# Цикл по минибатчам:  72%|███████▏  | 432/600 [00:10<00:04, 35.53it/s]
# Цикл по минибатчам:  73%|███████▎  | 436/600 [00:10<00:04, 34.27it/s]
# Цикл по минибатчам:  73%|███████▎  | 440/600 [00:10<00:04, 33.83it/s]
# Цикл по минибатчам:  74%|███████▍  | 444/600 [00:10<00:04, 34.01it/s]
# Цикл по минибатчам:  75%|███████▍  | 448/600 [00:10<00:04, 32.87it/s]
# Цикл по минибатчам:  75%|███████▌  | 452/600 [00:10<00:04, 31.72it/s]
# Цикл по минибатчам:  76%|███████▌  | 456/600 [00:10<00:04, 31.73it/s]
# Цикл по минибатчам:  77%|███████▋  | 460/600 [00:11<00:04, 31.02it/s]
# Цикл по минибатчам:  77%|███████▋  | 464/600 [00:11<00:04, 30.10it/s]
# Цикл по минибатчам:  78%|███████▊  | 468/600 [00:11<00:04, 29.57it/s]
# Цикл по минибатчам:  78%|███████▊  | 471/600 [00:11<00:04, 28.89it/s]
# Цикл по минибатчам:  79%|███████▉  | 474/600 [00:11<00:04, 28.33it/s]
# Цикл по минибатчам:  80%|███████▉  | 477/600 [00:11<00:04, 27.33it/s]
# Цикл по минибатчам:  80%|████████  | 480/600 [00:11<00:04, 27.87it/s]
# Цикл по минибатчам:  81%|████████  | 484/600 [00:11<00:04, 28.77it/s]
# Цикл по минибатчам:  81%|████████  | 487/600 [00:12<00:03, 28.63it/s]
# Цикл по минибатчам:  82%|████████▏ | 490/600 [00:12<00:03, 28.52it/s]
# Цикл по минибатчам:  82%|████████▏ | 493/600 [00:12<00:03, 28.79it/s]
# Цикл по минибатчам:  83%|████████▎ | 497/600 [00:12<00:03, 29.53it/s]
# Цикл по минибатчам:  84%|████████▎ | 501/600 [00:12<00:03, 29.83it/s]
# Цикл по минибатчам:  84%|████████▍ | 504/600 [00:12<00:03, 28.83it/s]
# Цикл по минибатчам:  84%|████████▍ | 507/600 [00:12<00:03, 27.24it/s]
# Цикл по минибатчам:  85%|████████▌ | 512/600 [00:12<00:02, 31.91it/s]
# Цикл по минибатчам:  86%|████████▌ | 517/600 [00:13<00:02, 35.79it/s]
# Цикл по минибатчам:  87%|████████▋ | 522/600 [00:13<00:02, 38.13it/s]
# Цикл по минибатчам:  88%|████████▊ | 527/600 [00:13<00:01, 40.71it/s]
# Цикл по минибатчам:  89%|████████▊ | 532/600 [00:13<00:01, 41.59it/s]
# Цикл по минибатчам:  90%|████████▉ | 537/600 [00:13<00:01, 42.76it/s]
# Цикл по минибатчам:  90%|█████████ | 542/600 [00:13<00:01, 44.11it/s]
# Цикл по минибатчам:  91%|█████████ | 547/600 [00:13<00:01, 44.19it/s]
# Цикл по минибатчам:  92%|█████████▏| 552/600 [00:13<00:01, 41.77it/s]
# Цикл по минибатчам:  93%|█████████▎| 557/600 [00:13<00:01, 42.55it/s]
# Цикл по минибатчам:  94%|█████████▎| 562/600 [00:14<00:00, 42.42it/s]
# Цикл по минибатчам:  94%|█████████▍| 567/600 [00:14<00:00, 43.10it/s]
# Цикл по минибатчам:  95%|█████████▌| 572/600 [00:14<00:00, 43.57it/s]
# Цикл по минибатчам:  96%|█████████▌| 577/600 [00:14<00:00, 44.40it/s]
# Цикл по минибатчам:  97%|█████████▋| 582/600 [00:14<00:00, 44.57it/s]
# Цикл по минибатчам:  98%|█████████▊| 587/600 [00:14<00:00, 44.55it/s]
# Цикл по минибатчам:  99%|█████████▊| 592/600 [00:14<00:00, 44.78it/s]
# Цикл по минибатчам: 100%|██████████| 600/600 [00:14<00:00, 40.20it/s]
# Epoch: 9
# Loader: train. Accuracy: 0.9861
# Цикл по минибатчам:   0%|          | 0/100 [00:00<?, ?it/s]
# Цикл по минибатчам:   6%|▌         | 6/100 [00:00<00:01, 51.49it/s]
# Цикл по минибатчам:  12%|█▏        | 12/100 [00:00<00:01, 48.87it/s]
# Цикл по минибатчам:  17%|█▋        | 17/100 [00:00<00:01, 47.17it/s]
# Цикл по минибатчам:  22%|██▏       | 22/100 [00:00<00:01, 47.11it/s]
# Цикл по минибатчам:  27%|██▋       | 27/100 [00:00<00:01, 47.38it/s]
# Цикл по минибатчам:  32%|███▏      | 32/100 [00:00<00:01, 47.63it/s]
# Цикл по минибатчам:  37%|███▋      | 37/100 [00:00<00:01, 47.30it/s]
# Цикл по минибатчам:  42%|████▏     | 42/100 [00:00<00:01, 42.96it/s]
# Цикл по минибатчам:  47%|████▋     | 47/100 [00:01<00:01, 44.41it/s]
# Цикл по минибатчам:  52%|█████▏    | 52/100 [00:01<00:01, 45.71it/s]
# Цикл по минибатчам:  57%|█████▋    | 57/100 [00:01<00:00, 45.94it/s]
# Цикл по минибатчам:  62%|██████▏   | 62/100 [00:01<00:00, 46.43it/s]
# Цикл по минибатчам:  67%|██████▋   | 67/100 [00:01<00:00, 46.62it/s]
# Цикл по минибатчам:  72%|███████▏  | 72/100 [00:01<00:00, 47.25it/s]
# Цикл по минибатчам:  77%|███████▋  | 77/100 [00:01<00:00, 46.90it/s]
# Цикл по минибатчам:  82%|████████▏ | 82/100 [00:01<00:00, 47.04it/s]
# Цикл по минибатчам:  87%|████████▋ | 87/100 [00:01<00:00, 45.09it/s]
# Цикл по минибатчам:  92%|█████████▏| 92/100 [00:02<00:00, 43.63it/s]
# Цикл по минибатчам: 100%|██████████| 100/100 [00:02<00:00, 45.93it/s]
# Цикл по Эпохам:  90%|█████████ | 9/10 [02:39<00:17, 17.62s/it]
# Loader: valid. Accuracy: 0.9544
# Цикл по минибатчам:   0%|          | 0/600 [00:00<?, ?it/s]
# Цикл по минибатчам:   1%|          | 4/600 [00:00<00:15, 37.59it/s]
# Цикл по минибатчам:   1%|▏         | 8/600 [00:00<00:15, 38.62it/s]
# Цикл по минибатчам:   2%|▏         | 13/600 [00:00<00:14, 41.73it/s]
# Цикл по минибатчам:   3%|▎         | 18/600 [00:00<00:13, 43.25it/s]
# Цикл по минибатчам:   4%|▍         | 23/600 [00:00<00:13, 41.51it/s]
# Цикл по минибатчам:   5%|▍         | 28/600 [00:00<00:14, 38.28it/s]
# Цикл по минибатчам:   5%|▌         | 32/600 [00:00<00:15, 37.32it/s]
# Цикл по минибатчам:   6%|▌         | 37/600 [00:00<00:14, 39.03it/s]
# Цикл по минибатчам:   7%|▋         | 41/600 [00:01<00:14, 38.87it/s]
# Цикл по минибатчам:   8%|▊         | 46/600 [00:01<00:13, 39.73it/s]
# Цикл по минибатчам:   8%|▊         | 51/600 [00:01<00:13, 40.92it/s]
# Цикл по минибатчам:   9%|▉         | 56/600 [00:01<00:12, 42.16it/s]
# Цикл по минибатчам:  10%|█         | 61/600 [00:01<00:12, 42.44it/s]
# Цикл по минибатчам:  11%|█         | 66/600 [00:01<00:13, 40.69it/s]
# Цикл по минибатчам:  12%|█▏        | 71/600 [00:01<00:13, 39.86it/s]
# Цикл по минибатчам:  13%|█▎        | 76/600 [00:01<00:13, 39.88it/s]
# Цикл по минибатчам:  14%|█▎        | 81/600 [00:02<00:12, 40.11it/s]
# Цикл по минибатчам:  14%|█▍        | 86/600 [00:02<00:12, 39.67it/s]
# Цикл по минибатчам:  15%|█▌        | 91/600 [00:02<00:12, 40.40it/s]
# Цикл по минибатчам:  16%|█▌        | 96/600 [00:02<00:12, 41.25it/s]
# Цикл по минибатчам:  17%|█▋        | 101/600 [00:02<00:11, 41.98it/s]
# Цикл по минибатчам:  18%|█▊        | 106/600 [00:02<00:11, 41.92it/s]
# Цикл по минибатчам:  18%|█▊        | 111/600 [00:02<00:12, 38.47it/s]
# Цикл по минибатчам:  19%|█▉        | 115/600 [00:02<00:12, 38.33it/s]
# Цикл по минибатчам:  20%|██        | 120/600 [00:02<00:12, 39.95it/s]
# Цикл по минибатчам:  21%|██        | 125/600 [00:03<00:11, 41.19it/s]
# Цикл по минибатчам:  22%|██▏       | 130/600 [00:03<00:11, 41.43it/s]
# Цикл по минибатчам:  22%|██▎       | 135/600 [00:03<00:11, 42.19it/s]
# Цикл по минибатчам:  23%|██▎       | 140/600 [00:03<00:10, 42.78it/s]
# Цикл по минибатчам:  24%|██▍       | 145/600 [00:03<00:10, 42.81it/s]
# Цикл по минибатчам:  25%|██▌       | 150/600 [00:03<00:11, 38.12it/s]
# Цикл по минибатчам:  26%|██▌       | 154/600 [00:03<00:11, 37.20it/s]
# Цикл по минибатчам:  26%|██▋       | 159/600 [00:03<00:11, 38.76it/s]
# Цикл по минибатчам:  27%|██▋       | 164/600 [00:04<00:10, 39.86it/s]
# Цикл по минибатчам:  28%|██▊       | 169/600 [00:04<00:10, 40.91it/s]
# Цикл по минибатчам:  29%|██▉       | 174/600 [00:04<00:10, 41.93it/s]
# Цикл по минибатчам:  30%|██▉       | 179/600 [00:04<00:09, 42.37it/s]
# Цикл по минибатчам:  31%|███       | 184/600 [00:04<00:09, 42.75it/s]
# Цикл по минибатчам:  32%|███▏      | 189/600 [00:04<00:10, 40.00it/s]
# Цикл по минибатчам:  32%|███▏      | 194/600 [00:04<00:10, 39.09it/s]
# Цикл по минибатчам:  33%|███▎      | 198/600 [00:04<00:10, 38.50it/s]
# Цикл по минибатчам:  34%|███▍      | 203/600 [00:05<00:09, 39.75it/s]
# Цикл по минибатчам:  35%|███▍      | 208/600 [00:05<00:09, 40.52it/s]
# Цикл по минибатчам:  36%|███▌      | 213/600 [00:05<00:09, 41.16it/s]
# Цикл по минибатчам:  36%|███▋      | 218/600 [00:05<00:09, 42.22it/s]
# Цикл по минибатчам:  37%|███▋      | 223/600 [00:05<00:08, 42.75it/s]
# Цикл по минибатчам:  38%|███▊      | 228/600 [00:05<00:08, 42.20it/s]
# Цикл по минибатчам:  39%|███▉      | 233/600 [00:05<00:10, 34.50it/s]
# Цикл по минибатчам:  40%|███▉      | 237/600 [00:05<00:11, 31.95it/s]
# Цикл по минибатчам:  40%|████      | 241/600 [00:06<00:11, 31.07it/s]
# Цикл по минибатчам:  41%|████      | 245/600 [00:06<00:11, 30.85it/s]
# Цикл по минибатчам:  42%|████▏     | 249/600 [00:06<00:11, 31.22it/s]
# Цикл по минибатчам:  42%|████▏     | 253/600 [00:06<00:11, 31.42it/s]
# Цикл по минибатчам:  43%|████▎     | 257/600 [00:06<00:10, 31.59it/s]
# Цикл по минибатчам:  44%|████▎     | 261/600 [00:06<00:11, 30.37it/s]
# Цикл по минибатчам:  44%|████▍     | 265/600 [00:06<00:10, 31.01it/s]
# Цикл по минибатчам:  45%|████▍     | 269/600 [00:07<00:10, 30.35it/s]
# Цикл по минибатчам:  46%|████▌     | 273/600 [00:07<00:11, 29.25it/s]
# Цикл по минибатчам:  46%|████▌     | 276/600 [00:07<00:11, 29.24it/s]
# Цикл по минибатчам:  46%|████▋     | 279/600 [00:07<00:11, 28.15it/s]
# Цикл по минибатчам:  47%|████▋     | 282/600 [00:07<00:11, 27.76it/s]
# Цикл по минибатчам:  48%|████▊     | 285/600 [00:07<00:11, 26.63it/s]
# Цикл по минибатчам:  48%|████▊     | 288/600 [00:07<00:12, 25.04it/s]
# Цикл по минибатчам:  48%|████▊     | 291/600 [00:07<00:13, 22.76it/s]
# Цикл по минибатчам:  49%|████▉     | 294/600 [00:08<00:13, 22.81it/s]
# Цикл по минибатчам:  50%|████▉     | 297/600 [00:08<00:12, 23.66it/s]
# Цикл по минибатчам:  50%|█████     | 301/600 [00:08<00:10, 27.62it/s]
# Цикл по минибатчам:  51%|█████     | 306/600 [00:08<00:09, 32.53it/s]
# Цикл по минибатчам:  52%|█████▏    | 311/600 [00:08<00:08, 35.69it/s]
# Цикл по минибатчам:  52%|█████▎    | 315/600 [00:08<00:07, 36.52it/s]
# Цикл по минибатчам:  53%|█████▎    | 319/600 [00:08<00:08, 34.51it/s]
# Цикл по минибатчам:  54%|█████▍    | 323/600 [00:08<00:07, 35.31it/s]
# Цикл по минибатчам:  55%|█████▍    | 328/600 [00:08<00:07, 37.25it/s]
# Цикл по минибатчам:  55%|█████▌    | 332/600 [00:09<00:07, 36.75it/s]
# Цикл по минибатчам:  56%|█████▌    | 337/600 [00:09<00:06, 38.74it/s]
# Цикл по минибатчам:  57%|█████▋    | 342/600 [00:09<00:06, 39.87it/s]
# Цикл по минибатчам:  58%|█████▊    | 347/600 [00:09<00:06, 40.63it/s]
# Цикл по минибатчам:  59%|█████▊    | 352/600 [00:09<00:06, 41.26it/s]
# Цикл по минибатчам:  60%|█████▉    | 357/600 [00:09<00:06, 38.37it/s]
# Цикл по минибатчам:  60%|██████    | 361/600 [00:09<00:06, 38.36it/s]
# Цикл по минибатчам:  61%|██████    | 366/600 [00:09<00:05, 39.30it/s]
# Цикл по минибатчам:  62%|██████▏   | 371/600 [00:10<00:05, 40.53it/s]
# Цикл по минибатчам:  63%|██████▎   | 376/600 [00:10<00:05, 40.47it/s]
# Цикл по минибатчам:  64%|██████▎   | 381/600 [00:10<00:05, 40.50it/s]
# Цикл по минибатчам:  64%|██████▍   | 386/600 [00:10<00:05, 41.32it/s]
# Цикл по минибатчам:  65%|██████▌   | 391/600 [00:10<00:04, 41.95it/s]
# Цикл по минибатчам:  66%|██████▌   | 396/600 [00:10<00:05, 39.58it/s]
# Цикл по минибатчам:  67%|██████▋   | 400/600 [00:10<00:05, 37.62it/s]
# Цикл по минибатчам:  67%|██████▋   | 404/600 [00:10<00:05, 38.17it/s]
# Цикл по минибатчам:  68%|██████▊   | 409/600 [00:11<00:04, 39.14it/s]
# Цикл по минибатчам:  69%|██████▉   | 413/600 [00:11<00:04, 38.47it/s]
# Цикл по минибатчам:  70%|██████▉   | 418/600 [00:11<00:04, 39.70it/s]
# Цикл по минибатчам:  70%|███████   | 423/600 [00:11<00:04, 40.86it/s]
# Цикл по минибатчам:  71%|███████▏  | 428/600 [00:11<00:04, 41.18it/s]
# Цикл по минибатчам:  72%|███████▏  | 433/600 [00:11<00:03, 41.82it/s]
# Цикл по минибатчам:  73%|███████▎  | 438/600 [00:11<00:04, 38.11it/s]
# Цикл по минибатчам:  74%|███████▍  | 443/600 [00:11<00:03, 39.64it/s]
# Цикл по минибатчам:  75%|███████▍  | 448/600 [00:11<00:03, 40.43it/s]
# Цикл по минибатчам:  76%|███████▌  | 453/600 [00:12<00:03, 41.19it/s]
# Цикл по минибатчам:  76%|███████▋  | 458/600 [00:12<00:03, 40.75it/s]
# Цикл по минибатчам:  77%|███████▋  | 463/600 [00:12<00:03, 41.37it/s]
# Цикл по минибатчам:  78%|███████▊  | 468/600 [00:12<00:03, 41.93it/s]
# Цикл по минибатчам:  79%|███████▉  | 473/600 [00:12<00:03, 42.08it/s]
# Цикл по минибатчам:  80%|███████▉  | 478/600 [00:12<00:03, 38.96it/s]
# Цикл по минибатчам:  80%|████████  | 482/600 [00:12<00:03, 38.79it/s]
# Цикл по минибатчам:  81%|████████  | 487/600 [00:12<00:02, 39.94it/s]
# Цикл по минибатчам:  82%|████████▏ | 492/600 [00:13<00:02, 41.01it/s]
# Цикл по минибатчам:  83%|████████▎ | 497/600 [00:13<00:02, 40.90it/s]
# Цикл по минибатчам:  84%|████████▎ | 502/600 [00:13<00:02, 41.65it/s]
# Цикл по минибатчам:  84%|████████▍ | 507/600 [00:13<00:02, 42.26it/s]
# Цикл по минибатчам:  85%|████████▌ | 512/600 [00:13<00:02, 42.07it/s]
# Цикл по минибатчам:  86%|████████▌ | 517/600 [00:13<00:02, 39.81it/s]
# Цикл по минибатчам:  87%|████████▋ | 522/600 [00:13<00:02, 38.58it/s]
# Цикл по минибатчам:  88%|████████▊ | 527/600 [00:13<00:01, 40.05it/s]
# Цикл по минибатчам:  89%|████████▊ | 532/600 [00:14<00:01, 40.39it/s]
# Цикл по минибатчам:  90%|████████▉ | 537/600 [00:14<00:01, 41.12it/s]
# Цикл по минибатчам:  90%|█████████ | 542/600 [00:14<00:01, 39.60it/s]
# Цикл по минибатчам:  91%|█████████ | 547/600 [00:14<00:01, 40.81it/s]
# Цикл по минибатчам:  92%|█████████▏| 552/600 [00:14<00:01, 41.00it/s]
# Цикл по минибатчам:  93%|█████████▎| 557/600 [00:14<00:01, 38.73it/s]
# Цикл по минибатчам:  94%|█████████▎| 561/600 [00:14<00:01, 37.52it/s]
# Цикл по минибатчам:  94%|█████████▍| 566/600 [00:14<00:00, 38.93it/s]
# Цикл по минибатчам:  95%|█████████▌| 570/600 [00:15<00:00, 38.82it/s]
# Цикл по минибатчам:  96%|█████████▌| 575/600 [00:15<00:00, 39.91it/s]
# Цикл по минибатчам:  96%|█████████▋| 579/600 [00:15<00:00, 39.41it/s]
# Цикл по минибатчам:  97%|█████████▋| 584/600 [00:15<00:00, 40.46it/s]
# Цикл по минибатчам:  98%|█████████▊| 589/600 [00:15<00:00, 41.39it/s]
# Цикл по минибатчам:  99%|█████████▉| 594/600 [00:15<00:00, 41.24it/s]
# Цикл по минибатчам: 100%|██████████| 600/600 [00:15<00:00, 38.03it/s]
# Epoch: 10
# Loader: train. Accuracy: 0.98575
# Цикл по минибатчам:   0%|          | 0/100 [00:00<?, ?it/s]
# Цикл по минибатчам:   5%|▌         | 5/100 [00:00<00:01, 47.75it/s]
# Цикл по минибатчам:  10%|█         | 10/100 [00:00<00:01, 45.82it/s]
# Цикл по минибатчам:  15%|█▌        | 15/100 [00:00<00:01, 45.12it/s]
# Цикл по минибатчам:  20%|██        | 20/100 [00:00<00:01, 42.55it/s]
# Цикл по минибатчам:  25%|██▌       | 25/100 [00:00<00:01, 44.06it/s]
# Цикл по минибатчам:  30%|███       | 30/100 [00:00<00:01, 44.76it/s]
# Цикл по минибатчам:  35%|███▌      | 35/100 [00:00<00:01, 41.81it/s]
# Цикл по минибатчам:  40%|████      | 40/100 [00:00<00:01, 38.60it/s]
# Цикл по минибатчам:  44%|████▍     | 44/100 [00:01<00:01, 38.69it/s]
# Цикл по минибатчам:  49%|████▉     | 49/100 [00:01<00:01, 40.79it/s]
# Цикл по минибатчам:  54%|█████▍    | 54/100 [00:01<00:01, 42.70it/s]
# Цикл по минибатчам:  59%|█████▉    | 59/100 [00:01<00:00, 43.75it/s]
# Цикл по минибатчам:  64%|██████▍   | 64/100 [00:01<00:00, 42.82it/s]
# Цикл по минибатчам:  69%|██████▉   | 69/100 [00:01<00:00, 44.41it/s]
# Цикл по минибатчам:  74%|███████▍  | 74/100 [00:01<00:00, 45.26it/s]
# Цикл по минибатчам:  79%|███████▉  | 79/100 [00:01<00:00, 44.13it/s]
# Цикл по минибатчам:  84%|████████▍ | 84/100 [00:01<00:00, 41.29it/s]
# Цикл по минибатчам:  89%|████████▉ | 89/100 [00:02<00:00, 43.04it/s]
# Цикл по минибатчам:  94%|█████████▍| 94/100 [00:02<00:00, 44.63it/s]
# Цикл по минибатчам: 100%|██████████| 100/100 [00:02<00:00, 43.15it/s]
# Цикл по Эпохам: 100%|██████████| 10/10 [02:57<00:00, 17.76s/it]
# Loader: valid. Accuracy: 0.9739

# %% [markdown]
# ### Задание. Протестируйте разные функции активации.
# Попробуйте разные функции активации. Для каждой функции активации посчитайте массив validation accuracy. Лучше реализовать это в виде функции, берущей на вход активацию и получающей массив из accuracies.

# %%
elu_accuracy = accuracy["valid"]

# %%
import tqdm

# %%
# YOUR CODE. Do the same thing with other activations (it's better to wrap into a function that returns a list of accuracies)

def test_activation_function(activation, criterion=criterion, loaders=loaders):
    #YOUR CODE
    model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(784, 128),
        activation(),
        nn.Linear(128, 128),
        activation(),
        nn.Linear(128, 10)
    )

    optimizer = torch.optim.Adam(model.parameters())

    max_epochs = 10
    accuracy = {"train": [], "valid": []}
    for epoch in tqdm.tqdm(range(max_epochs)):
        for k, dataloader in loaders.items():
            epoch_correct = 0
            epoch_all = 0
            for x_batch, y_batch in dataloader:
                if k == "train":
                    model.train()
                    optimizer.zero_grad()
                    outp = model(x_batch)
                else:
                    model.eval()
                    with torch.no_grad():
                        outp = model(x_batch)
                preds = outp.argmax(-1)
                correct = sum(preds == y_batch)
                all = len(preds)
                epoch_correct += correct.item()
                epoch_all += all
                if k == "train":
                    loss = criterion(outp, y_batch)
                    loss.backward()
                    optimizer.step()
            accuracy[k].append(epoch_correct/epoch_all)

    return accuracy['valid']

# %%
plain_accuracy = test_activation_function(Identical)
relu_accuracy = test_activation_function(nn.ReLU)                   #YOUR CODE
leaky_relu_accuracy = test_activation_function(nn.LeakyReLU)        #YOUR CODE

# %% [markdown]
# ### Accuracy
# Построим график accuracy/epoch для каждой функции активации.

# %%
sns.set(style="darkgrid", font_scale=1.4)

plt.figure(figsize=(16, 10))
plt.title("Valid accuracy")
plt.plot(range(max_epochs), plain_accuracy, label="No activation", linewidth=2)
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.title("Valid accuracy")
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# **Вопрос 4.** Какая из активаций показала наивысший `accuracy` к концу обучения?
#
# **Ответ:**
#
# При перезапуске всего ноутбука победитель постоянно меняетя. Сначала ReLU был лучшим, затем ELU, потом LeakyReLU

# %% [markdown]
# ## Часть 2.2 Сверточные нейронные сети

# %% [markdown]
# ### Ядра
# Сначала немного поработам с самим понятием ядра свёртки.

# %%
# !wget https://img.the-village.kz/the-village.com.kz/post-cover/5x5-I6oiwjmq79dMCZMEbA-default.jpg -O sample_photo.jpg

# %%
import cv2
sns.set(style="white")
img = cv2.imread("sample_photo.jpg")
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 8))
plt.imshow(RGB_img)
plt.show()

# %% [markdown]
# Попробуйте посмотреть как различные свертки влияют на фото. Например, попробуйте
# A)
# ```
# [0, 0, 0],
# [0, 1, 0],
# [0, 0, 0]
# ```
# Б)
# ```
# [0, 1, 0],
# [0, -2, 0],
# [0, 1, 0]
# ```
# В)
# ```
# [0, 0, 0],
# [1, -2, 1],
# [0, 0, 0]
# ```
# Г)
# ```
# [0, 1, 0],
# [1, -4, 1],
# [0, 1, 0]
# ```
# Д)
# ```
# [0, -1, 0],
# [-1, 5, -1],
# [0, -1, 0]
# ```
# Е)
# ```
# [0.0625, 0.125, 0.0625],
# [0.125, 0.25, 0.125],
# [0.0625, 0.125, 0.0625]
# ```
#
# Не стесняйтесь пробовать свои варианты!

# %%
img_t = torch.from_numpy(RGB_img).type(torch.float32).unsqueeze(0)
kernel = torch.tensor([
    [0.0625, 0.125, 0.0625],
    [0.125, 0.25, 0.125],
    [0.0625, 0.125, 0.0625]
]).reshape(1, 1, 3, 3).type(torch.float32)

kernel = kernel.repeat(3, 3, 1, 1)
img_t = img_t.permute(0, 3, 1, 2)  # [BS, H, W, C] -> [BS, C, H, W]
img_t = nn.ReflectionPad2d(1)(img_t)  # Pad Image for same output size

result = F.conv2d(img_t, kernel)[0]  #

# %%
plt.figure(figsize=(12, 8))
result_np = result.permute(1, 2, 0).numpy() / 256 / 3

plt.imshow(result_np)
plt.show()

# %% [markdown]
# **Вопрос 5.** Как можно описать действия ядер, приведенных выше? Сопоставьте для каждой буквы число.
#
# 1) Размытие
#
# 2) Увеличение резкости
#
# 3) Тождественное преобразование
#
# 4) Выделение вертикальных границ
#
# 5) Выделение горизонтальных границ
#
# 6) Выделение границ
#
# **Ответ:**
# А - 3
#
# Б - 5
#
# В - 4
#
# Г - 6
#
# Д - 2
#
# Е - 1

# %% [markdown]
# ### Задание. Реализуйте LeNet
#
# Если мы сделаем параметры сверток обучаемыми, то можем добиться хороших результатов для задач компьютерного зрения. Реализуйте архитектуру LeNet, предложенную еще в 1998 году!
# На этот раз используйте модульную структуру (без помощи класса Sequential).
#
# Наша нейронная сеть будет состоять из
# * Свёртки 3x3 (1 карта на входе, 6 на выходе) с активацией ReLU;
# * MaxPooling-а 2x2;
# * Свёртки 3x3 (6 карт на входе, 16 на выходе) с активацией ReLU;
# * MaxPooling-а 2x2;
# * Уплощения (nn.Flatten);
# * Полносвязного слоя со 120 нейронами и активацией ReLU;
# * Полносвязного слоя с 84 нейронами и активацией ReLU;
# * Выходного слоя из 10 нейронов.

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        self.flatten = nn.Flatten()
        # 1 input image channel, 6 output channels, 3x3 square conv kernel
        self.conv1 = nn.Conv2d(1, 6, 3)
        self.pool1 = nn.MaxPool2d(2, 2)         #YOUR CODE
        self.conv2 = nn.Conv2d(6, 16, 3)        #YOUR CODE
        self.pool2 = nn.MaxPool2d(2, 2)         #YOUR CODE
        self.fc1 = nn.Linear(400, 120)          #YOUR CODE
        self.fc2 = nn.Linear(120, 84)           #YOUR CODE
        self.fc3 = nn.Linear(84, 10)            #YOUR CODE

    def forward(self, x):
        x = F.relu(self.conv1(x))               #YOUR CODE. Apply layers created in __init__.
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)

        return x

# %%
model = LeNet().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

loaders = {"train": train_dataloader, "valid": valid_dataloader}

# %% [markdown]
# ### Задание. Обучите CNN
# Используйте код обучения, который вы написали для полносвязной нейронной сети.

# %%
from tqdm import tqdm_notebook

# %%
# <YOUR CODE>
max_epochs = 10
accuracy = {"train": [], "valid": []}
for epoch in tqdm_notebook(range(max_epochs)):
    for k, dataloader in loaders.items():
        epoch_correct = 0
        epoch_all = 0
        for x_batch, y_batch in dataloader:
            if k == "train":
                 model.train()
                 optimizer.zero_grad()
                 outp = model(x_batch.to(device))
            else:
                 model.eval()
                 with torch.no_grad():
                    outp = model(x_batch.to(device))
            preds = outp.argmax(-1)
            correct = sum(preds == y_batch.to(device))     # YOUR CODE GOES HERE
            all = len(preds)                    # YOUR CODE GOES HERE
            epoch_correct += correct.item()
            epoch_all += all
            if k == "train":
                loss = criterion(outp, y_batch.to(device))
                # YOUR CODE. Calculate gradients and make a step of your optimizer
                loss.backward()
                optimizer.step()
        if k == "train":
            print(f"Epoch: {epoch+1}")
        print(f"Loader: {k}. Accuracy: {epoch_correct/epoch_all}")
        accuracy[k].append(epoch_correct/epoch_all)

# %%
lenet_accuracy = accuracy["valid"]

# %% [markdown]
# Сравним с предыдущем пунктом

# %%
plt.figure(figsize=(16, 10))
plt.title("Valid accuracy")
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.plot(range(max_epochs), lenet_accuracy, label="LeNet", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %%
f'lenet_accuracy : {lenet_accuracy[-1]:.2f}'

# %% [markdown]
# **Вопрос 6**
# Какое `accuracy` получается после обучения с точностью до двух знаков после запятой?
#
# **Ответ:**
# 0.70
